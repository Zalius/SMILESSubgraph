# %%
import random
import argparse
import numpy as np
import networkx as nx

import pickle

import torch
import torch.nn.functional as F
import torch_sparse
from torch import Tensor
from torch.nn import Linear
from torch.utils.data import DataLoader
from torch_geometric.utils import negative_sampling, to_networkx
from typing import Union, Tuple
from torch_geometric.typing import OptPairTensor, Adj, OptTensor, Size
from torch_sparse import SparseTensor, matmul
from torch_geometric.nn.conv import MessagePassing

from ogb.linkproppred import PygLinkPropPredDataset, Evaluator

# %%
# Load the ogbl-ddi dataset
# dataset_name = 'ogbl-ddi'
dataset = PygLinkPropPredDataset(name='ogbl-ddi')
# dataset = PygLinkPropPredDataset(name='ogbl-ddi',
#                                      transform=T.ToSparseTensor())
print(f'The ogbl-ddi dataset has {len(dataset)} graph(s).')
# Out:
# The ogbl-ddi dataset has 1 graph(s).

# %%
with open('data/node_features_PCA.pickle', 'rb') as handle:
    node_features = pickle.load(handle)
with open('data/train_pos.pickle', 'rb') as handle:
    train_pos = pickle.load(handle)
with open('data/valid_pos.pickle', 'rb') as handle:
    valid_pos = pickle.load(handle)
with open('data/valid_neg.pickle', 'rb') as handle:
    valid_neg = pickle.load(handle)
with open('data/test_pos.pickle', 'rb') as handle:
    test_pos = pickle.load(handle)
with open('data/test_neg.pickle', 'rb') as handle:
    test_neg = pickle.load(handle)
with open('data/nodes.pickle', 'rb') as handle:
    nodes = pickle.load(handle)
with open('data/nodes_removed.pickle', 'rb') as handle:
    nodes_removed = pickle.load(handle)

# %%
print(f'Number of training positive edges: {train_pos.shape[0]}')
print(f'Number of validation positive edges: {valid_pos.shape[0]}')
print(f'Number of validation negative edges: {valid_neg.shape[0]}')
print(f'Number of test positive edges: {test_pos.shape[0]}')
print(f'Number of test negative edges: {test_neg.shape[0]}')
# Out:
# Number of training positive edges: 887234
# Number of validation positive edges: 111117
# Number of validation negative edges: 74182
# Number of test positive edges: 114869
# Number of test negative edges: 70962

# %%
nodes = torch.tensor(nodes)

# %%
data = dataset[0].subgraph(nodes)

# %%
def get_spd_matrix(G, S, max_spd=5):
    spd_matrix = np.zeros((G.number_of_nodes(), len(S)), dtype=np.float32)
    for i, node_S in enumerate(S):
        for node, length in nx.shortest_path_length(G, source=node_S).items():
            spd_matrix[node, i] = min(length, max_spd)
    return spd_matrix

# %%
class Logger(object):
    def __init__(self, runs, info=None):
        self.info = info
        self.results = [[] for _ in range(runs)]

    def add_result(self, run, result):
        assert len(result) == 2
        assert run >= 0 and run < len(self.results)
        self.results[run].append(result)

    def print_statistics(self, run=None):
        if run is not None:
            result = 100 * torch.tensor(self.results[run])
            argmax = result[:, 0].argmax().item()
            print(f'Run {run + 1:02d}:')
            print(f'Highest Valid: {result[:, 0].max():.2f}')
            print(f'   Final Test: {result[argmax, 1]:.2f}')
        else:
            result = 100 * torch.tensor(self.results)
            best_results = []
            for r in result:
                valid = r[:, 0].max().item()
                test = r[r[:, 0].argmax(), 1].item()
                best_results.append((valid, test))
            best_result = torch.tensor(best_results)
            print(f'All runs:')
            r = best_result[:, 0]
            print(f'Highest Valid: {r.mean():.4f} ± {r.std():.4f}')
            r = best_result[:, 1]
            print(f'   Final Test: {r.mean():.4f} ± {r.std():.4f}')


class SAGEConv(MessagePassing):
    r"""The GraphSAGE operator from the `"Inductive Representation Learning on
    Large Graphs" <https://arxiv.org/abs/1706.02216>`_ paper

    .. math::
        \mathbf{x}^{\prime}_i = \mathbf{W}_1 \mathbf{x}_i + \mathbf{W}_2 \cdot
        \mathrm{mean}_{j \in \mathcal{N(i)}} \mathbf{x}_j

    Args:
        in_channels (int or tuple): Size of each input sample. A tuple
            corresponds to the sizes of source and target dimensionalities.
        out_channels (int): Size of each output sample.
        normalize (bool, optional): If set to :obj:`True`, output features
            will be :math:`\ell_2`-normalized, *i.e.*,
            :math:`\frac{\mathbf{x}^{\prime}_i}
            {\| \mathbf{x}^{\prime}_i \|_2}`.
            (default: :obj:`False`)
        root_weight (bool, optional): If set to :obj:`False`, the layer will
            not add transformed root node features to the output.
            (default: :obj:`True`)
        bias (bool, optional): If set to :obj:`False`, the layer will not learn
            an additive bias. (default: :obj:`True`)
        **kwargs (optional): Additional arguments of
            :class:`torch_geometric.nn.conv.MessagePassing`.
    """
    def __init__(self, in_channels: Union[int, Tuple[int, int]],
                 out_channels: int, normalize: bool = False,
                 root_weight: bool = True,
                 bias: bool = True, **kwargs):  # yapf: disable
        kwargs.setdefault('aggr', 'mean')
        super(SAGEConv, self).__init__(**kwargs)

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.normalize = normalize
        self.root_weight = root_weight

        if isinstance(in_channels, int):
            in_channels = (in_channels, in_channels)

        self.lin_l = Linear(in_channels[0], out_channels, bias=bias)
        if self.root_weight:
            self.lin_r = Linear(in_channels[1], out_channels, bias=False)

        self.reset_parameters()

    def reset_parameters(self):
        self.lin_l.reset_parameters()
        if self.root_weight:
            self.lin_r.reset_parameters()


    def forward(self, x: Union[Tensor, OptPairTensor], edge_index: Adj,
                edge_attr: OptTensor = None, size: Size = None) -> Tensor:
        """"""
        if isinstance(x, Tensor):
            x: OptPairTensor = (x, x)

        # Node and edge feature dimensionalites need to match.
        if isinstance(edge_index, Tensor):
            assert edge_attr is not None
            assert x[0].size(-1) == edge_attr.size(-1)
        elif isinstance(edge_index, SparseTensor):
            assert x[0].size(-1) == edge_index.size(-1)

        # propagate_type: (x: OptPairTensor, edge_attr: OptTensor)
        out = self.propagate(edge_index, x=x, edge_attr=edge_attr, size=size)
        out = self.lin_l(out)

        x_r = x[1]
        if self.root_weight and x_r is not None:
            out += self.lin_r(x_r)

        if self.normalize:
            out = F.normalize(out, p=2., dim=-1)

        return out


    def message(self, x_j: Tensor, edge_attr: Tensor) -> Tensor:
        return F.relu(x_j + edge_attr)


    def __repr__(self):
        return '{}({}, {})'.format(self.__class__.__name__, self.in_channels,
                                   self.out_channels)


class GraphSAGE(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers, dropout):
        super(GraphSAGE,self).__init__()
        self.convs = torch.nn.ModuleList()
        self.convs.append(SAGEConv(in_channels, hidden_channels))
        for _ in range(num_layers - 2):
            self.convs.append(SAGEConv(hidden_channels, hidden_channels))
        self.convs.append(SAGEConv(hidden_channels, out_channels))
        self.dropout = dropout

    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()

    def forward(self, x, adj_t, edge_attr, emb_ea):
        edge_attr = torch.mm(edge_attr, emb_ea)
        for conv in self.convs[:-1]:
            x = conv(x, adj_t, edge_attr)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.convs[-1](x, adj_t, edge_attr)
        return x


class LinkPredictor(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers,
                 dropout):
        super(LinkPredictor, self).__init__()

        self.lins = torch.nn.ModuleList()
        self.lins.append(torch.nn.Linear(in_channels, hidden_channels))
        for _ in range(num_layers - 2):
            self.lins.append(torch.nn.Linear(hidden_channels, hidden_channels))
        self.lins.append(torch.nn.Linear(hidden_channels, out_channels))

        self.dropout = dropout

    def reset_parameters(self):
        for lin in self.lins:
            lin.reset_parameters()

    def forward(self, x_i, x_j):
        x = x_i * x_j
        for lin in self.lins[:-1]:
            x = lin(x)
            x = F.relu(x)
            x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.lins[-1](x)
        return torch.sigmoid(x)

# %%
def train(model, predictor, edge_attr, x, emb_ea, adj_t, train_edge, optimizer, batch_size):
    edge_index = adj_t

    model.train()
    predictor.train()

    pos_train_edge = train_edge.to(x.device)

    total_loss = total_examples = 0
    for perm in DataLoader(range(pos_train_edge.size(0)), batch_size, shuffle=True):
        optimizer.zero_grad()

        h = model(x, adj_t, edge_attr, emb_ea)

        edge = pos_train_edge[perm].t()

        pos_out = predictor(h[edge[0]], h[edge[1]])
        pos_loss = -torch.log(pos_out + 1e-15).mean()

        edge = negative_sampling(edge_index, num_nodes=x.size(0),
                                 num_neg_samples=perm.size(0), method='dense')

        neg_out = predictor(h[edge[0]], h[edge[1]])
        neg_loss = -torch.log(1 - neg_out + 1e-15).mean()

        loss = pos_loss + neg_loss
        loss.backward()

        torch.nn.utils.clip_grad_norm_(x, 1.0)
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        torch.nn.utils.clip_grad_norm_(predictor.parameters(), 1.0)

        optimizer.step()

        num_examples = pos_out.size(0)
        total_loss += loss.item() * num_examples
        total_examples += num_examples

    return total_loss / total_examples

# %%
all_pos_valid_pred = []
all_neg_valid_pred = []
all_pos_test_pred = []
all_neg_test_pred = []
@torch.no_grad()
def test(model, predictor, edge_attr, x, emb_ea, adj_t, pos_valid, neg_valid, pos_test, neg_test, evaluator, batch_size):
    model.eval()
    predictor.eval()

    h = model(x, adj_t, edge_attr, emb_ea)

    pos_valid_edge = pos_valid.to(x.device)
    neg_valid_edge = neg_valid.to(x.device)
    pos_test_edge = pos_test.to(x.device)
    neg_test_edge = neg_test.to(x.device)

    pos_valid_preds = []
    for perm in DataLoader(range(pos_valid_edge.size(0)), batch_size):
        edge = pos_valid_edge[perm].t()
        pos_valid_preds += [predictor(h[edge[0]], h[edge[1]]).squeeze().cpu()]
    pos_valid_pred = torch.cat(pos_valid_preds, dim=0)

    neg_valid_preds = []
    for perm in DataLoader(range(neg_valid_edge.size(0)), batch_size):
        edge = neg_valid_edge[perm].t()
        neg_valid_preds += [predictor(h[edge[0]], h[edge[1]]).squeeze().cpu()]
    neg_valid_pred = torch.cat(neg_valid_preds, dim=0)

    pos_test_preds = []
    for perm in DataLoader(range(pos_test_edge.size(0)), batch_size):
        edge = pos_test_edge[perm].t()
        pos_test_preds += [predictor(h[edge[0]], h[edge[1]]).squeeze().cpu()]
    pos_test_pred = torch.cat(pos_test_preds, dim=0)

    neg_test_preds = []
    for perm in DataLoader(range(neg_test_edge.size(0)), batch_size):
        edge = neg_test_edge[perm].t()
        neg_test_preds += [predictor(h[edge[0]], h[edge[1]]).squeeze().cpu()]
    neg_test_pred = torch.cat(neg_test_preds, dim=0)

    results = {}
    for K in [20, 50, 100]:
        evaluator.K = K
        valid_hits = evaluator.eval({
            'y_pred_pos': pos_valid_pred,
            'y_pred_neg': neg_valid_pred,
        })[f'hits@{K}']
        test_hits = evaluator.eval({
            'y_pred_pos': pos_test_pred,
            'y_pred_neg': neg_test_pred,
        })[f'hits@{K}']
        
        if float(valid_hits) > 0.3 and float(test_hits) > 0.3:
            all_pos_valid_pred.append(pos_valid_pred)
            all_neg_valid_pred.append(neg_valid_pred)
            all_pos_test_pred.append(pos_test_pred)
            all_neg_test_pred.append(neg_test_pred)
        


        results[f'Hits@{K}'] = (valid_hits, test_hits)

    return results

# %%
node_features.size()
# Out:
# torch.Size([3539, 96])

# %%
device = torch.device('cpu')
num_layers = 3
num_samples = 5
node_emb = 96
hidden_channels = 96
dropout = 0.2
batch_size = 64 * 1024
lr = 0.003
epochs = 400
log_steps = 1
eval_steps = 1
runs = 1

# %%
edge_index = data.edge_index.to(device)

# %%
model = GraphSAGE(node_emb, hidden_channels, hidden_channels,
                      num_layers, dropout).to(device)
emb = torch.nn.Embedding.from_pretrained(node_features, freeze=False).to(device)
emb_ea = torch.nn.Embedding(num_samples, node_emb).to(device)
predictor = LinkPredictor(hidden_channels, hidden_channels, 1,
                              num_layers+1, dropout).to(device)

# %%
# model = GraphSAGE(node_emb, hidden_channels, hidden_channels, 
#                       num_layers, dropout).to(device)
# emb = torch.nn.Embedding(data.num_nodes, node_emb).to(device)
# emb_ea = torch.nn.Embedding(num_samples, node_emb).to(device)
# predictor = LinkPredictor(hidden_channels, hidden_channels, 1,
#                               num_layers+1, dropout).to(device)

# %%
emb.weight
# Out:
# Parameter containing:
# tensor([[-7.4891e-02,  1.4025e-02,  1.2281e+00,  ..., -3.5495e-04,
#          -8.6586e-04,  5.4261e-04],
#         [ 3.2602e-01, -4.1421e-01,  9.6334e-01,  ...,  8.1558e-04,
#          -5.5911e-04,  8.3106e-05],
#         [ 3.2602e-01, -4.1421e-01,  9.6334e-01,  ...,  8.1558e-04,
#          -5.5911e-04,  8.3106e-05],
#         ...,
#         [ 2.9628e-01,  4.8572e-01,  9.0430e-01,  ...,  3.3874e-05,
#           1.8812e-03,  4.0076e-03],
#         [ 1.8145e+00, -9.2635e-02,  2.6241e-01,  ...,  3.2484e-04,
#          -7.3765e-04,  7.6157e-04],
#         [ 4.0041e-01, -5.6188e-01,  1.1202e+00,  ...,  2.0947e-03,
#          -9.5269e-04,  1.2110e-03]], requires_grad=True)

# %%
print('Number of parameters:',
          sum(p.numel() for p in list(model.parameters()) +
          list(predictor.parameters()) + list(emb.parameters()) + list(emb_ea.parameters())))
# Out:
# Number of parameters: 423841

# %%
np.random.seed(0)
nx_graph = to_networkx(data, to_undirected=True)
node_mask = []
for _ in range(num_samples):
    node_mask.append(np.random.choice(500, size=200, replace=False))
node_mask = np.array(node_mask)
node_subset = np.random.choice(nx_graph.number_of_nodes(), size=500, replace=False)
spd = get_spd_matrix(G=nx_graph, S=node_subset, max_spd=5)
spd = torch.Tensor(spd).to(device)

# %%
edge_attr = spd[edge_index, :].mean(0)[:, node_mask].mean(2)

# %%
a_max = torch.max(edge_attr, dim=0, keepdim=True)[0]
a_min = torch.min(edge_attr, dim=0, keepdim=True)[0]
edge_attr = (edge_attr - a_min) / (a_max - a_min + 1e-6)

# %%
import argparse

# %%
parser = argparse.ArgumentParser(description='Link_Pred_DDI')
parser.add_argument('--device', type=int, default=0)
parser.add_argument('--num_layers', type=int, default=3)
parser.add_argument('--num_samples', type=int, default=5)
parser.add_argument('--node_emb', type=int, default=96)
parser.add_argument('--hidden_channels', type=int, default=96)
parser.add_argument('--dropout', type=float, default=0.2)
parser.add_argument('--batch_size', type=int, default=64 * 1024)
parser.add_argument('--lr', type=float, default=0.003)
parser.add_argument('--epochs', type=int, default=200)
parser.add_argument('--log_steps', type=int, default=1)
parser.add_argument('--eval_steps', type=int, default=1)
parser.add_argument('--runs', type=int, default=1)
parser.add_argument("-f", "--file", required=False)
args = parser.parse_args()
print(args)
# Out:
# Namespace(device=0, num_layers=3, num_samples=5, node_emb=96, hidden_channels=96, dropout=0.2, batch_size=65536, lr=0.003, epochs=200, log_steps=1, eval_steps=1, runs=1, file='C:\\Users\\AGM2\\AppData\\Roaming\\jupyter\\runtime\\kernel-e5cec5c6-faa2-4b69-ad5b-af2760c0f904.json')

# %%
evaluator = Evaluator(name='ogbl-ddi')
loggers = {
    'Hits@20': Logger(runs, args),
    'Hits@50': Logger(args.runs, args),
    'Hits@100': Logger(args.runs, args),
}

# %%
for run in range(runs):
    random.seed(run)
    torch.manual_seed(run)
#     torch.nn.init.xavier_uniform_(emb.weight)
#     torch.nn.init.xavier_uniform_(emb_ea.weight)
    model.reset_parameters()
    predictor.reset_parameters()
    optimizer = torch.optim.Adam(
        list(model.parameters()) + list(emb.parameters()) +
        list(emb_ea.parameters()) + list(predictor.parameters()), lr=lr)

    for epoch in range(1, 1 + epochs):
        loss = train(model, predictor, edge_attr, emb.weight, emb_ea.weight, edge_index, train_pos,
                      optimizer, batch_size)

        if epoch % eval_steps == 0:
            results = test(model, predictor, edge_attr, emb.weight, emb_ea.weight, edge_index, valid_pos, valid_neg, test_pos, test_neg,
                            evaluator, batch_size)
            for key, result in results.items():
                loggers[key].add_result(run, result)

            if epoch % log_steps == 0:
                for key, result in results.items():
                    valid_hits, test_hits = result
                    print(key)
                    print(f'Run: {run + 1:02d}, '
                          f'Epoch: {epoch:02d}, '
                          f'Loss: {loss:.4f}, '
                          f'Valid: {100 * valid_hits:.2f}%, '
                          f'Test: {100 * test_hits:.2f}%')
                print('---')

    for key in loggers.keys():
        print(key)
        loggers[key].print_statistics(run)

for key in loggers.keys():
    print(key)
    loggers[key].print_statistics()
# Out:
# Hits@20
# Run: 01, Epoch: 01, Loss: 1.3696, Valid: 2.07%, Test: 1.99%
# Hits@50
# Run: 01, Epoch: 01, Loss: 1.3696, Valid: 3.36%, Test: 2.87%
# Hits@100
# Run: 01, Epoch: 01, Loss: 1.3696, Valid: 5.10%, Test: 4.68%
# ---
# Hits@20
# Run: 01, Epoch: 02, Loss: 1.4234, Valid: 2.31%, Test: 2.00%
# Hits@50
# Run: 01, Epoch: 02, Loss: 1.4234, Valid: 3.86%, Test: 3.55%
# Hits@100
# Run: 01, Epoch: 02, Loss: 1.4234, Valid: 5.73%, Test: 5.31%
# ---
# Hits@20
# Run: 01, Epoch: 03, Loss: 1.0864, Valid: 0.23%, Test: 0.39%
# Hits@50
# Run: 01, Epoch: 03, Loss: 1.0864, Valid: 0.76%, Test: 0.92%
# Hits@100
# Run: 01, Epoch: 03, Loss: 1.0864, Valid: 1.87%, Test: 2.23%
# ---
# Hits@20
# Run: 01, Epoch: 04, Loss: 0.8934, Valid: 1.67%, Test: 3.25%
# Hits@50
# Run: 01, Epoch: 04, Loss: 0.8934, Valid: 3.07%, Test: 5.12%
# Hits@100
# Run: 01, Epoch: 04, Loss: 0.8934, Valid: 5.64%, Test: 7.63%
# ---
# Hits@20
# Run: 01, Epoch: 05, Loss: 0.8402, Valid: 2.86%, Test: 4.92%
# Hits@50
# Run: 01, Epoch: 05, Loss: 0.8402, Valid: 4.60%, Test: 7.86%
# Hits@100
# Run: 01, Epoch: 05, Loss: 0.8402, Valid: 7.02%, Test: 9.89%
# ---
# Hits@20
# Run: 01, Epoch: 06, Loss: 0.7918, Valid: 5.45%, Test: 8.51%
# Hits@50
# Run: 01, Epoch: 06, Loss: 0.7918, Valid: 8.77%, Test: 10.86%
# Hits@100
# Run: 01, Epoch: 06, Loss: 0.7918, Valid: 12.05%, Test: 13.82%
# ---
# Hits@20
# Run: 01, Epoch: 07, Loss: 0.7491, Valid: 5.50%, Test: 7.86%
# Hits@50
# Run: 01, Epoch: 07, Loss: 0.7491, Valid: 9.21%, Test: 10.87%
# Hits@100
# Run: 01, Epoch: 07, Loss: 0.7491, Valid: 12.99%, Test: 13.84%
# ---
# Hits@20
# Run: 01, Epoch: 08, Loss: 0.7145, Valid: 13.99%, Test: 6.47%
# Hits@50
# Run: 01, Epoch: 08, Loss: 0.7145, Valid: 16.57%, Test: 10.97%
# Hits@100
# Run: 01, Epoch: 08, Loss: 0.7145, Valid: 19.29%, Test: 15.07%
# ---
# Hits@20
# Run: 01, Epoch: 09, Loss: 0.6828, Valid: 20.61%, Test: 14.38%
# Hits@50
# Run: 01, Epoch: 09, Loss: 0.6828, Valid: 22.96%, Test: 20.20%
# Hits@100
# Run: 01, Epoch: 09, Loss: 0.6828, Valid: 24.92%, Test: 24.80%
# ---
# Hits@20
# Run: 01, Epoch: 10, Loss: 0.6495, Valid: 14.94%, Test: 11.39%
# Hits@50
# Run: 01, Epoch: 10, Loss: 0.6495, Valid: 18.48%, Test: 16.07%
# Hits@100
# Run: 01, Epoch: 10, Loss: 0.6495, Valid: 22.26%, Test: 21.29%
# ---
# Hits@20
# Run: 01, Epoch: 11, Loss: 0.6276, Valid: 16.80%, Test: 12.81%
# Hits@50
# Run: 01, Epoch: 11, Loss: 0.6276, Valid: 21.62%, Test: 19.32%
# Hits@100
# Run: 01, Epoch: 11, Loss: 0.6276, Valid: 26.61%, Test: 24.36%
# ---
# Hits@20
# Run: 01, Epoch: 12, Loss: 0.6114, Valid: 23.72%, Test: 13.32%
# Hits@50
# Run: 01, Epoch: 12, Loss: 0.6114, Valid: 28.98%, Test: 22.30%
# Hits@100
# Run: 01, Epoch: 12, Loss: 0.6114, Valid: 33.01%, Test: 27.48%
# ---
# Hits@20
# Run: 01, Epoch: 13, Loss: 0.5959, Valid: 16.50%, Test: 10.87%
# Hits@50
# Run: 01, Epoch: 13, Loss: 0.5959, Valid: 22.51%, Test: 18.34%
# Hits@100
# Run: 01, Epoch: 13, Loss: 0.5959, Valid: 27.95%, Test: 25.02%
# ---
# Hits@20
# Run: 01, Epoch: 14, Loss: 0.5801, Valid: 17.91%, Test: 10.93%
# Hits@50
# Run: 01, Epoch: 14, Loss: 0.5801, Valid: 26.10%, Test: 23.12%
# Hits@100
# Run: 01, Epoch: 14, Loss: 0.5801, Valid: 33.74%, Test: 31.15%
# ---
# Hits@20
# Run: 01, Epoch: 15, Loss: 0.5676, Valid: 13.33%, Test: 10.88%
# Hits@50
# Run: 01, Epoch: 15, Loss: 0.5676, Valid: 21.54%, Test: 20.73%
# Hits@100
# Run: 01, Epoch: 15, Loss: 0.5676, Valid: 29.80%, Test: 28.53%
# ---
# Hits@20
# Run: 01, Epoch: 16, Loss: 0.5613, Valid: 17.74%, Test: 15.28%
# Hits@50
# Run: 01, Epoch: 16, Loss: 0.5613, Valid: 27.94%, Test: 28.97%
# Hits@100
# Run: 01, Epoch: 16, Loss: 0.5613, Valid: 36.52%, Test: 35.63%
# ---
# Hits@20
# Run: 01, Epoch: 17, Loss: 0.5487, Valid: 18.27%, Test: 16.77%
# Hits@50
# Run: 01, Epoch: 17, Loss: 0.5487, Valid: 30.29%, Test: 28.30%
# Hits@100
# Run: 01, Epoch: 17, Loss: 0.5487, Valid: 37.93%, Test: 37.71%
# ---
# Hits@20
# Run: 01, Epoch: 18, Loss: 0.5361, Valid: 23.62%, Test: 19.21%
# Hits@50
# Run: 01, Epoch: 18, Loss: 0.5361, Valid: 35.48%, Test: 32.15%
# Hits@100
# Run: 01, Epoch: 18, Loss: 0.5361, Valid: 42.68%, Test: 41.65%
# ---
# Hits@20
# Run: 01, Epoch: 19, Loss: 0.5280, Valid: 28.32%, Test: 18.97%
# Hits@50
# Run: 01, Epoch: 19, Loss: 0.5280, Valid: 37.12%, Test: 31.23%
# Hits@100
# Run: 01, Epoch: 19, Loss: 0.5280, Valid: 43.45%, Test: 40.06%
# ---
# Hits@20
# Run: 01, Epoch: 20, Loss: 0.5206, Valid: 22.22%, Test: 18.22%
# Hits@50
# Run: 01, Epoch: 20, Loss: 0.5206, Valid: 33.83%, Test: 33.49%
# Hits@100
# Run: 01, Epoch: 20, Loss: 0.5206, Valid: 44.77%, Test: 41.55%
# ---
# Hits@20
# Run: 01, Epoch: 21, Loss: 0.5105, Valid: 13.40%, Test: 15.54%
# Hits@50
# Run: 01, Epoch: 21, Loss: 0.5105, Valid: 26.24%, Test: 23.10%
# Hits@100
# Run: 01, Epoch: 21, Loss: 0.5105, Valid: 33.72%, Test: 32.07%
# ---
# Hits@20
# Run: 01, Epoch: 22, Loss: 0.5043, Valid: 20.11%, Test: 18.04%
# Hits@50
# Run: 01, Epoch: 22, Loss: 0.5043, Valid: 31.32%, Test: 27.38%
# Hits@100
# Run: 01, Epoch: 22, Loss: 0.5043, Valid: 38.14%, Test: 37.49%
# ---
# Hits@20
# Run: 01, Epoch: 23, Loss: 0.4943, Valid: 27.54%, Test: 20.96%
# Hits@50
# Run: 01, Epoch: 23, Loss: 0.4943, Valid: 34.45%, Test: 29.08%
# Hits@100
# Run: 01, Epoch: 23, Loss: 0.4943, Valid: 42.82%, Test: 37.39%
# ---
# Hits@20
# Run: 01, Epoch: 24, Loss: 0.4883, Valid: 27.60%, Test: 20.68%
# Hits@50
# Run: 01, Epoch: 24, Loss: 0.4883, Valid: 34.80%, Test: 29.91%
# Hits@100
# Run: 01, Epoch: 24, Loss: 0.4883, Valid: 43.94%, Test: 42.46%
# ---
# Hits@20
# Run: 01, Epoch: 25, Loss: 0.4805, Valid: 20.95%, Test: 19.49%
# Hits@50
# Run: 01, Epoch: 25, Loss: 0.4805, Valid: 30.63%, Test: 26.55%
# Hits@100
# Run: 01, Epoch: 25, Loss: 0.4805, Valid: 38.34%, Test: 36.94%
# ---
# Hits@20
# Run: 01, Epoch: 26, Loss: 0.4741, Valid: 19.59%, Test: 13.48%
# Hits@50
# Run: 01, Epoch: 26, Loss: 0.4741, Valid: 27.45%, Test: 23.31%
# Hits@100
# Run: 01, Epoch: 26, Loss: 0.4741, Valid: 37.50%, Test: 34.59%
# ---
# Hits@20
# Run: 01, Epoch: 27, Loss: 0.4651, Valid: 27.65%, Test: 17.29%
# Hits@50
# Run: 01, Epoch: 27, Loss: 0.4651, Valid: 33.54%, Test: 27.84%
# Hits@100
# Run: 01, Epoch: 27, Loss: 0.4651, Valid: 42.54%, Test: 36.20%
# ---
# Hits@20
# Run: 01, Epoch: 28, Loss: 0.4646, Valid: 24.31%, Test: 19.51%
# Hits@50
# Run: 01, Epoch: 28, Loss: 0.4646, Valid: 33.37%, Test: 29.68%
# Hits@100
# Run: 01, Epoch: 38, Loss: 0.4129, Valid: 35.12%, Test: 24.44%
# Hits@100
# Run: 01, Epoch: 38, Loss: 0.4129, Valid: 42.55%, Test: 33.92%
# ---
# Hits@20
# Run: 01, Epoch: 39, Loss: 0.4123, Valid: 18.22%, Test: 18.48%
# Hits@50
# Run: 01, Epoch: 39, Loss: 0.4123, Valid: 28.21%, Test: 30.35%
# Hits@100
# Run: 01, Epoch: 39, Loss: 0.4123, Valid: 39.72%, Test: 38.92%
# ---
# Hits@20
# Run: 01, Epoch: 40, Loss: 0.4053, Valid: 21.91%, Test: 18.59%
# Hits@50
# Run: 01, Epoch: 40, Loss: 0.4053, Valid: 32.74%, Test: 28.73%
# Hits@100
# Run: 01, Epoch: 40, Loss: 0.4053, Valid: 44.63%, Test: 37.48%
# ---
# Hits@20
# Run: 01, Epoch: 41, Loss: 0.4016, Valid: 28.08%, Test: 21.30%
# Hits@50
# Run: 01, Epoch: 41, Loss: 0.4016, Valid: 37.82%, Test: 31.37%
# Hits@100
# Run: 01, Epoch: 41, Loss: 0.4016, Valid: 47.78%, Test: 42.11%
# ---
# Hits@20
# Run: 01, Epoch: 42, Loss: 0.3996, Valid: 25.21%, Test: 20.98%
# Hits@50
# Run: 01, Epoch: 42, Loss: 0.3996, Valid: 36.12%, Test: 31.09%
# Hits@100
# Run: 01, Epoch: 42, Loss: 0.3996, Valid: 47.34%, Test: 38.67%
# ---
# Hits@20
# Run: 01, Epoch: 43, Loss: 0.3939, Valid: 23.81%, Test: 17.41%
# Hits@50
# Run: 01, Epoch: 43, Loss: 0.3939, Valid: 33.37%, Test: 30.18%
# Hits@100
# Run: 01, Epoch: 43, Loss: 0.3939, Valid: 44.52%, Test: 40.60%
# ---
# Hits@20
# Run: 01, Epoch: 44, Loss: 0.3909, Valid: 23.18%, Test: 18.27%
# Hits@50
# Run: 01, Epoch: 44, Loss: 0.3909, Valid: 31.14%, Test: 28.90%
# Hits@100
# Run: 01, Epoch: 44, Loss: 0.3909, Valid: 46.32%, Test: 39.07%
# ---
# Hits@20
# Run: 01, Epoch: 45, Loss: 0.3852, Valid: 24.34%, Test: 19.12%
# Hits@50
# Run: 01, Epoch: 45, Loss: 0.3852, Valid: 36.21%, Test: 26.32%
# Hits@100
# Run: 01, Epoch: 45, Loss: 0.3852, Valid: 47.65%, Test: 35.66%
# ---
# Hits@20
# Run: 01, Epoch: 46, Loss: 0.3838, Valid: 29.54%, Test: 15.46%
# Hits@50
# Run: 01, Epoch: 46, Loss: 0.3838, Valid: 41.29%, Test: 24.07%
# Hits@100
# Run: 01, Epoch: 46, Loss: 0.3838, Valid: 50.87%, Test: 36.47%
# ---
# Hits@20
# Run: 01, Epoch: 47, Loss: 0.3799, Valid: 20.88%, Test: 13.41%
# Hits@50
# Run: 01, Epoch: 47, Loss: 0.3799, Valid: 34.27%, Test: 25.33%
# Hits@100
# Run: 01, Epoch: 47, Loss: 0.3799, Valid: 45.44%, Test: 34.93%
# ---
# Hits@20
# Run: 01, Epoch: 48, Loss: 0.3763, Valid: 23.63%, Test: 13.33%
# Hits@50
# Run: 01, Epoch: 48, Loss: 0.3763, Valid: 34.39%, Test: 25.47%
# Hits@100
# Run: 01, Epoch: 48, Loss: 0.3763, Valid: 44.39%, Test: 36.27%
# ---
# Hits@20
# Run: 01, Epoch: 49, Loss: 0.3754, Valid: 27.23%, Test: 17.54%
# Hits@50
# Run: 01, Epoch: 49, Loss: 0.3754, Valid: 34.63%, Test: 25.42%
# Hits@100
# Run: 01, Epoch: 49, Loss: 0.3754, Valid: 46.02%, Test: 36.25%
# ---
# Hits@20
# Run: 01, Epoch: 50, Loss: 0.3725, Valid: 25.97%, Test: 16.97%
# Hits@50
# Run: 01, Epoch: 50, Loss: 0.3725, Valid: 35.26%, Test: 26.88%
# Hits@100
# Run: 01, Epoch: 50, Loss: 0.3725, Valid: 44.64%, Test: 35.35%
# ---
# Hits@20
# Run: 01, Epoch: 51, Loss: 0.3690, Valid: 25.12%, Test: 18.26%
# Hits@50
# Run: 01, Epoch: 51, Loss: 0.3690, Valid: 34.82%, Test: 28.47%
# Hits@100
# Run: 01, Epoch: 51, Loss: 0.3690, Valid: 45.51%, Test: 37.40%
# ---
# Hits@20
# Run: 01, Epoch: 52, Loss: 0.3695, Valid: 25.42%, Test: 11.71%
# Hits@50
# Run: 01, Epoch: 52, Loss: 0.3695, Valid: 36.87%, Test: 26.51%
# Hits@100
# Run: 01, Epoch: 52, Loss: 0.3695, Valid: 49.59%, Test: 36.70%
# ---
# Hits@20
# Run: 01, Epoch: 53, Loss: 0.3652, Valid: 25.92%, Test: 14.07%
# Hits@50
# Run: 01, Epoch: 53, Loss: 0.3652, Valid: 36.56%, Test: 27.41%
# Hits@100
# Run: 01, Epoch: 53, Loss: 0.3652, Valid: 45.93%, Test: 40.44%
# ---
# Hits@20
# Run: 01, Epoch: 54, Loss: 0.3632, Valid: 31.48%, Test: 16.50%
# Hits@50
# Run: 01, Epoch: 54, Loss: 0.3632, Valid: 39.95%, Test: 27.13%
# Hits@100
# Run: 01, Epoch: 54, Loss: 0.3632, Valid: 49.33%, Test: 37.67%
# ---
# Hits@20
# Run: 01, Epoch: 55, Loss: 0.3636, Valid: 27.75%, Test: 20.47%
# Hits@50
# Run: 01, Epoch: 55, Loss: 0.3636, Valid: 39.01%, Test: 28.11%
# Hits@100
# Run: 01, Epoch: 55, Loss: 0.3636, Valid: 48.37%, Test: 34.79%
# ---
# Hits@20
# Run: 01, Epoch: 56, Loss: 0.3610, Valid: 31.33%, Test: 16.11%
# Hits@50
# Run: 01, Epoch: 56, Loss: 0.3610, Valid: 41.98%, Test: 25.90%
# Hits@100
# Run: 01, Epoch: 56, Loss: 0.3610, Valid: 49.57%, Test: 37.20%
# ---
# Hits@20
# Run: 01, Epoch: 57, Loss: 0.3592, Valid: 22.99%, Test: 10.58%
# Hits@50
# Run: 01, Epoch: 57, Loss: 0.3592, Valid: 31.28%, Test: 20.17%
# Hits@100
# Run: 01, Epoch: 57, Loss: 0.3592, Valid: 39.78%, Test: 28.27%
# ---
# Hits@20
# Run: 01, Epoch: 58, Loss: 0.3586, Valid: 28.19%, Test: 8.70%
# Hits@50
# Run: 01, Epoch: 58, Loss: 0.3586, Valid: 37.84%, Test: 17.14%
# Hits@100
# Run: 01, Epoch: 58, Loss: 0.3586, Valid: 48.11%, Test: 30.28%
# ---
# Hits@20
# Run: 01, Epoch: 59, Loss: 0.3545, Valid: 30.23%, Test: 11.14%
# Hits@50
# Run: 01, Epoch: 59, Loss: 0.3545, Valid: 40.01%, Test: 24.25%
# Hits@100
# Run: 01, Epoch: 59, Loss: 0.3545, Valid: 48.92%, Test: 33.86%
# ---
# Hits@20
# Run: 01, Epoch: 60, Loss: 0.3527, Valid: 31.91%, Test: 16.89%
# Hits@50
# Run: 01, Epoch: 60, Loss: 0.3527, Valid: 39.38%, Test: 29.61%
# Hits@100
# Run: 01, Epoch: 60, Loss: 0.3527, Valid: 47.16%, Test: 39.08%
# ---
# Hits@20
# Run: 01, Epoch: 61, Loss: 0.3487, Valid: 30.75%, Test: 14.39%
# Hits@50
# Run: 01, Epoch: 61, Loss: 0.3487, Valid: 40.28%, Test: 25.22%
# Hits@100
# Run: 01, Epoch: 61, Loss: 0.3487, Valid: 48.23%, Test: 39.24%
# ---
# Hits@20
# Run: 01, Epoch: 62, Loss: 0.3456, Valid: 31.00%, Test: 11.24%
# Hits@50
# Run: 01, Epoch: 62, Loss: 0.3456, Valid: 38.96%, Test: 19.89%
# Hits@100
# Run: 01, Epoch: 62, Loss: 0.3456, Valid: 46.35%, Test: 32.95%
# ---
# Hits@20
# Run: 01, Epoch: 63, Loss: 0.3455, Valid: 28.19%, Test: 13.24%
# Hits@50
# Run: 01, Epoch: 63, Loss: 0.3455, Valid: 35.99%, Test: 21.51%
# Hits@100
# Run: 01, Epoch: 63, Loss: 0.3455, Valid: 44.34%, Test: 30.29%
# ---
# Hits@20
# Run: 01, Epoch: 64, Loss: 0.3454, Valid: 28.68%, Test: 10.29%
# Hits@50
# Run: 01, Epoch: 64, Loss: 0.3454, Valid: 38.17%, Test: 20.96%
# Hits@100
# Run: 01, Epoch: 64, Loss: 0.3454, Valid: 47.62%, Test: 32.52%
# ---
# Hits@20
# Run: 01, Epoch: 65, Loss: 0.3459, Valid: 29.33%, Test: 12.72%
# Hits@50
# Run: 01, Epoch: 65, Loss: 0.3459, Valid: 40.69%, Test: 21.93%
# Hits@100
# Run: 01, Epoch: 65, Loss: 0.3459, Valid: 48.07%, Test: 32.36%
# ---
# Hits@20
# Run: 01, Epoch: 66, Loss: 0.3410, Valid: 28.84%, Test: 12.13%
# Hits@50
# Run: 01, Epoch: 66, Loss: 0.3410, Valid: 37.73%, Test: 21.29%
# Hits@100
# Run: 01, Epoch: 66, Loss: 0.3410, Valid: 46.96%, Test: 33.84%
# ---
# Hits@20
# Run: 01, Epoch: 67, Loss: 0.3416, Valid: 29.36%, Test: 12.37%
# Hits@50
# Run: 01, Epoch: 67, Loss: 0.3416, Valid: 43.13%, Test: 20.85%
# Hits@100
# Run: 01, Epoch: 67, Loss: 0.3416, Valid: 50.13%, Test: 34.43%
# ---
# Hits@20
# Run: 01, Epoch: 68, Loss: 0.3371, Valid: 25.28%, Test: 12.67%
# Hits@50
# Run: 01, Epoch: 68, Loss: 0.3371, Valid: 39.02%, Test: 21.08%
# Hits@100
# Run: 01, Epoch: 68, Loss: 0.3371, Valid: 47.65%, Test: 31.07%
# ---
# Hits@20
# Run: 01, Epoch: 69, Loss: 0.3371, Valid: 28.46%, Test: 11.15%
# Hits@50
# Run: 01, Epoch: 69, Loss: 0.3371, Valid: 37.25%, Test: 19.04%
# Hits@100
# Run: 01, Epoch: 69, Loss: 0.3371, Valid: 45.73%, Test: 28.39%
# ---
# Hits@20
# Run: 01, Epoch: 70, Loss: 0.3341, Valid: 26.98%, Test: 12.42%
# Hits@50
# Run: 01, Epoch: 70, Loss: 0.3341, Valid: 38.98%, Test: 24.02%
# Hits@100
# Run: 01, Epoch: 70, Loss: 0.3341, Valid: 45.47%, Test: 33.70%
# ---
# Hits@20
# Run: 01, Epoch: 71, Loss: 0.3343, Valid: 30.26%, Test: 15.09%
# Hits@50
# Run: 01, Epoch: 71, Loss: 0.3343, Valid: 39.74%, Test: 23.49%
# Hits@100
# Run: 01, Epoch: 71, Loss: 0.3343, Valid: 47.56%, Test: 34.87%
# ---
# Hits@20
# Run: 01, Epoch: 72, Loss: 0.3337, Valid: 33.54%, Test: 14.63%
# Hits@50
# Run: 01, Epoch: 72, Loss: 0.3337, Valid: 42.40%, Test: 24.79%
# Hits@100
# Run: 01, Epoch: 72, Loss: 0.3337, Valid: 49.96%, Test: 34.36%
# ---
# Hits@20
# Run: 01, Epoch: 73, Loss: 0.3331, Valid: 32.19%, Test: 13.96%
# Hits@50
# Run: 01, Epoch: 73, Loss: 0.3331, Valid: 40.74%, Test: 21.37%
# Hits@100
# Run: 01, Epoch: 73, Loss: 0.3331, Valid: 46.11%, Test: 32.55%
# ---
# Hits@20
# Run: 01, Epoch: 74, Loss: 0.3297, Valid: 30.62%, Test: 13.90%
# Hits@50
# Run: 01, Epoch: 74, Loss: 0.3297, Valid: 43.00%, Test: 22.78%
# Hits@100
# Run: 01, Epoch: 74, Loss: 0.3297, Valid: 51.99%, Test: 37.25%
# ---
# Hits@20
# Run: 01, Epoch: 75, Loss: 0.3308, Valid: 30.32%, Test: 18.07%
# Hits@50
# Run: 01, Epoch: 75, Loss: 0.3308, Valid: 42.36%, Test: 25.56%
# Hits@100
# Run: 01, Epoch: 75, Loss: 0.3308, Valid: 50.61%, Test: 39.02%
# ---
# Hits@20
# Run: 01, Epoch: 76, Loss: 0.3275, Valid: 24.27%, Test: 16.82%
# Hits@50
# Run: 01, Epoch: 76, Loss: 0.3275, Valid: 34.34%, Test: 28.04%
# Hits@100
# Run: 01, Epoch: 76, Loss: 0.3275, Valid: 43.25%, Test: 37.56%
# ---
# Hits@20
# Run: 01, Epoch: 77, Loss: 0.3285, Valid: 31.49%, Test: 18.65%
# Hits@50
# Run: 01, Epoch: 77, Loss: 0.3285, Valid: 40.52%, Test: 28.25%
# Hits@100
# Run: 01, Epoch: 77, Loss: 0.3285, Valid: 47.79%, Test: 40.26%
# ---
# Hits@20
# Run: 01, Epoch: 78, Loss: 0.3262, Valid: 30.28%, Test: 13.03%
# Hits@50
# Run: 01, Epoch: 78, Loss: 0.3262, Valid: 42.68%, Test: 20.16%
# Hits@100
# Run: 01, Epoch: 78, Loss: 0.3262, Valid: 49.59%, Test: 32.13%
# ---
# Hits@20
# Run: 01, Epoch: 79, Loss: 0.3215, Valid: 32.20%, Test: 12.96%
# Hits@50
# Run: 01, Epoch: 79, Loss: 0.3215, Valid: 42.93%, Test: 18.77%
# Hits@100
# Run: 01, Epoch: 79, Loss: 0.3215, Valid: 52.19%, Test: 37.00%
# ---
# Hits@20
# Run: 01, Epoch: 80, Loss: 0.3212, Valid: 33.33%, Test: 10.50%
# Hits@50
# Run: 01, Epoch: 80, Loss: 0.3212, Valid: 43.63%, Test: 17.32%
# Hits@100
# Run: 01, Epoch: 80, Loss: 0.3212, Valid: 51.16%, Test: 30.25%
# ---
# Hits@20
# Run: 01, Epoch: 81, Loss: 0.3215, Valid: 32.80%, Test: 13.86%
# Hits@50
# Run: 01, Epoch: 81, Loss: 0.3215, Valid: 42.84%, Test: 21.03%
# Hits@100
# Run: 01, Epoch: 81, Loss: 0.3215, Valid: 50.33%, Test: 35.71%
# ---
# Hits@20
# Run: 01, Epoch: 82, Loss: 0.3212, Valid: 32.41%, Test: 12.49%
# Hits@50
# Run: 01, Epoch: 82, Loss: 0.3212, Valid: 42.20%, Test: 20.60%
# Hits@100
# Run: 01, Epoch: 82, Loss: 0.3212, Valid: 49.43%, Test: 31.59%
# ---
# Hits@20
# Run: 01, Epoch: 83, Loss: 0.3193, Valid: 32.97%, Test: 12.72%
# Hits@50
# Run: 01, Epoch: 83, Loss: 0.3193, Valid: 44.68%, Test: 18.46%
# Hits@100
# Run: 01, Epoch: 83, Loss: 0.3193, Valid: 51.71%, Test: 34.46%
# ---
# Hits@20
# Run: 01, Epoch: 84, Loss: 0.3158, Valid: 34.64%, Test: 14.82%
# Hits@50
# Run: 01, Epoch: 84, Loss: 0.3158, Valid: 44.32%, Test: 21.69%
# Hits@100
# Run: 01, Epoch: 84, Loss: 0.3158, Valid: 51.85%, Test: 34.72%
# ---
# Hits@20
# Run: 01, Epoch: 85, Loss: 0.3158, Valid: 35.46%, Test: 16.64%
# Hits@50
# Run: 01, Epoch: 85, Loss: 0.3158, Valid: 44.80%, Test: 26.23%
# Hits@100
# Run: 01, Epoch: 85, Loss: 0.3158, Valid: 51.91%, Test: 38.37%
# ---
# Hits@20
# Run: 01, Epoch: 86, Loss: 0.3158, Valid: 35.53%, Test: 10.20%
# Hits@50
# Run: 01, Epoch: 86, Loss: 0.3158, Valid: 44.81%, Test: 16.90%
# Hits@100
# Run: 01, Epoch: 86, Loss: 0.3158, Valid: 52.01%, Test: 30.33%
# ---
# Hits@20
# Run: 01, Epoch: 87, Loss: 0.3176, Valid: 33.78%, Test: 19.62%
# Hits@50
# Run: 01, Epoch: 87, Loss: 0.3176, Valid: 42.96%, Test: 29.22%
# Hits@100
# Run: 01, Epoch: 87, Loss: 0.3176, Valid: 49.12%, Test: 40.76%
# ---
# Hits@20
# Run: 01, Epoch: 88, Loss: 0.3170, Valid: 32.51%, Test: 11.09%
# Hits@50
# Run: 01, Epoch: 88, Loss: 0.3170, Valid: 42.89%, Test: 17.54%
# Hits@100
# Run: 01, Epoch: 88, Loss: 0.3170, Valid: 52.45%, Test: 32.07%
# ---
# Hits@20
# Run: 01, Epoch: 89, Loss: 0.3153, Valid: 37.15%, Test: 13.45%
# Hits@50
# Run: 01, Epoch: 89, Loss: 0.3153, Valid: 45.95%, Test: 19.72%
# Hits@100
# Run: 01, Epoch: 89, Loss: 0.3153, Valid: 54.89%, Test: 32.37%
# ---
# Hits@20
# Run: 01, Epoch: 90, Loss: 0.3130, Valid: 32.95%, Test: 24.05%
# Hits@50
# Run: 01, Epoch: 90, Loss: 0.3130, Valid: 44.06%, Test: 29.65%
# Hits@100
# Run: 01, Epoch: 90, Loss: 0.3130, Valid: 50.25%, Test: 40.29%
# ---
# Hits@20
# Run: 01, Epoch: 91, Loss: 0.3111, Valid: 40.18%, Test: 10.54%
# Hits@50
# Run: 01, Epoch: 91, Loss: 0.3111, Valid: 48.03%, Test: 19.56%
# Hits@100
# Run: 01, Epoch: 91, Loss: 0.3111, Valid: 55.14%, Test: 33.71%
# ---
# Hits@20
# Run: 01, Epoch: 92, Loss: 0.3091, Valid: 32.36%, Test: 16.91%
# Hits@50
# Run: 01, Epoch: 92, Loss: 0.3091, Valid: 43.14%, Test: 24.37%
# Hits@100
# Run: 01, Epoch: 92, Loss: 0.3091, Valid: 50.12%, Test: 34.85%
# ---
# Hits@20
# Run: 01, Epoch: 93, Loss: 0.3083, Valid: 34.49%, Test: 13.26%
# Hits@50
# Run: 01, Epoch: 93, Loss: 0.3083, Valid: 45.81%, Test: 22.26%
# Hits@100
# Run: 01, Epoch: 93, Loss: 0.3083, Valid: 53.49%, Test: 37.27%
# ---
# Hits@20
# Run: 01, Epoch: 94, Loss: 0.3074, Valid: 32.70%, Test: 12.82%
# Hits@50
# Run: 01, Epoch: 94, Loss: 0.3074, Valid: 45.74%, Test: 21.79%
# Hits@100
# Run: 01, Epoch: 94, Loss: 0.3074, Valid: 53.99%, Test: 34.08%
# ---
# Hits@20
# Run: 01, Epoch: 95, Loss: 0.3051, Valid: 33.81%, Test: 17.60%
# Hits@50
# Run: 01, Epoch: 95, Loss: 0.3051, Valid: 43.29%, Test: 27.18%
# Hits@100
# Run: 01, Epoch: 95, Loss: 0.3051, Valid: 50.98%, Test: 37.37%
# ---
# Hits@20
# Run: 01, Epoch: 96, Loss: 0.3048, Valid: 37.41%, Test: 9.32%
# Hits@50
# Run: 01, Epoch: 96, Loss: 0.3048, Valid: 47.17%, Test: 17.63%
# Hits@100
# Run: 01, Epoch: 96, Loss: 0.3048, Valid: 54.52%, Test: 28.76%
# ---
# Hits@20
# Run: 01, Epoch: 97, Loss: 0.3034, Valid: 36.91%, Test: 10.77%
# Hits@50
# Run: 01, Epoch: 97, Loss: 0.3034, Valid: 48.10%, Test: 19.25%
# Hits@100
# Run: 01, Epoch: 97, Loss: 0.3034, Valid: 55.45%, Test: 31.47%
# ---
# Hits@20
# Run: 01, Epoch: 98, Loss: 0.3041, Valid: 36.85%, Test: 9.23%
# Hits@50
# Run: 01, Epoch: 98, Loss: 0.3041, Valid: 45.31%, Test: 15.18%
# Hits@100
# Run: 01, Epoch: 98, Loss: 0.3041, Valid: 53.40%, Test: 30.07%
# ---
# Hits@20
# Run: 01, Epoch: 99, Loss: 0.3012, Valid: 37.79%, Test: 12.66%
# Hits@50
# Run: 01, Epoch: 99, Loss: 0.3012, Valid: 48.57%, Test: 22.21%
# Hits@100
# Run: 01, Epoch: 99, Loss: 0.3012, Valid: 56.38%, Test: 38.93%
# ---
# Hits@20
# Run: 01, Epoch: 100, Loss: 0.3029, Valid: 37.58%, Test: 11.75%
# Hits@50
# Run: 01, Epoch: 100, Loss: 0.3029, Valid: 46.22%, Test: 19.28%
# Hits@100
# Run: 01, Epoch: 100, Loss: 0.3029, Valid: 54.03%, Test: 30.20%
# ---
# Hits@20
# Run: 01, Epoch: 101, Loss: 0.3012, Valid: 34.37%, Test: 14.87%
# Hits@50
# Run: 01, Epoch: 101, Loss: 0.3012, Valid: 46.69%, Test: 23.94%
# Hits@100
# Run: 01, Epoch: 101, Loss: 0.3012, Valid: 53.02%, Test: 37.98%
# ---
# Hits@20
# Run: 01, Epoch: 102, Loss: 0.2992, Valid: 35.58%, Test: 11.64%
# Hits@50
# Run: 01, Epoch: 102, Loss: 0.2992, Valid: 46.49%, Test: 18.60%
# Hits@100
# Run: 01, Epoch: 102, Loss: 0.2992, Valid: 53.65%, Test: 29.47%
# ---
# Hits@20
# Run: 01, Epoch: 103, Loss: 0.3010, Valid: 37.67%, Test: 12.40%
# Hits@50
# Run: 01, Epoch: 103, Loss: 0.3010, Valid: 44.77%, Test: 18.49%
# Hits@100
# Run: 01, Epoch: 103, Loss: 0.3010, Valid: 52.44%, Test: 29.71%
# ---
# Hits@20
# Run: 01, Epoch: 104, Loss: 0.2997, Valid: 40.02%, Test: 9.98%
# Hits@50
# Run: 01, Epoch: 104, Loss: 0.2997, Valid: 48.30%, Test: 17.44%
# Hits@100
# Run: 01, Epoch: 104, Loss: 0.2997, Valid: 55.50%, Test: 26.60%
# ---
# Hits@20
# Run: 01, Epoch: 105, Loss: 0.2976, Valid: 39.10%, Test: 8.93%
# Hits@50
# Run: 01, Epoch: 105, Loss: 0.2976, Valid: 47.25%, Test: 17.65%
# Hits@100
# Run: 01, Epoch: 105, Loss: 0.2976, Valid: 55.95%, Test: 27.50%
# ---
# Hits@20
# Run: 01, Epoch: 106, Loss: 0.2960, Valid: 35.19%, Test: 8.18%
# Hits@50
# Run: 01, Epoch: 106, Loss: 0.2960, Valid: 44.09%, Test: 15.54%
# Hits@100
# Run: 01, Epoch: 106, Loss: 0.2960, Valid: 51.10%, Test: 29.77%
# ---
# Hits@20
# Run: 01, Epoch: 107, Loss: 0.2940, Valid: 38.68%, Test: 9.84%
# Hits@50
# Run: 01, Epoch: 107, Loss: 0.2940, Valid: 47.97%, Test: 17.96%
# Hits@100
# Run: 01, Epoch: 107, Loss: 0.2940, Valid: 54.82%, Test: 32.20%
# ---
# Hits@20
# Run: 01, Epoch: 108, Loss: 0.2928, Valid: 35.64%, Test: 11.97%
# Hits@50
# Run: 01, Epoch: 108, Loss: 0.2928, Valid: 47.13%, Test: 20.09%
# Hits@100
# Run: 01, Epoch: 108, Loss: 0.2928, Valid: 53.52%, Test: 32.95%
# ---
# Hits@20
# Run: 01, Epoch: 109, Loss: 0.2908, Valid: 39.64%, Test: 15.30%
# Hits@50
# Run: 01, Epoch: 109, Loss: 0.2908, Valid: 47.68%, Test: 26.57%
# Hits@100
# Run: 01, Epoch: 109, Loss: 0.2908, Valid: 55.20%, Test: 40.52%
# ---
# Hits@20
# Run: 01, Epoch: 110, Loss: 0.2920, Valid: 37.12%, Test: 13.36%
# Hits@50
# Run: 01, Epoch: 110, Loss: 0.2920, Valid: 46.52%, Test: 19.74%
# Hits@100
# Run: 01, Epoch: 110, Loss: 0.2920, Valid: 52.81%, Test: 30.86%
# ---
# Hits@20
# Run: 01, Epoch: 111, Loss: 0.2946, Valid: 38.79%, Test: 14.46%
# Hits@50
# Run: 01, Epoch: 111, Loss: 0.2946, Valid: 46.18%, Test: 21.82%
# Hits@100
# Run: 01, Epoch: 111, Loss: 0.2946, Valid: 53.72%, Test: 31.84%
# ---
# Hits@20
# Run: 01, Epoch: 112, Loss: 0.2933, Valid: 34.51%, Test: 10.43%
# Hits@50
# Run: 01, Epoch: 112, Loss: 0.2933, Valid: 48.57%, Test: 18.66%
# Hits@100
# Run: 01, Epoch: 112, Loss: 0.2933, Valid: 55.49%, Test: 32.13%
# ---
# Hits@20
# Run: 01, Epoch: 113, Loss: 0.2915, Valid: 37.16%, Test: 12.19%
# Hits@50
# Run: 01, Epoch: 113, Loss: 0.2915, Valid: 49.08%, Test: 20.43%
# Hits@100
# Run: 01, Epoch: 113, Loss: 0.2915, Valid: 55.62%, Test: 29.89%
# ---
# Hits@20
# Run: 01, Epoch: 114, Loss: 0.2900, Valid: 41.40%, Test: 13.87%
# Hits@50
# Run: 01, Epoch: 114, Loss: 0.2900, Valid: 50.20%, Test: 21.92%
# Hits@100
# Run: 01, Epoch: 114, Loss: 0.2900, Valid: 56.43%, Test: 36.94%
# ---
# Hits@20
# Run: 01, Epoch: 115, Loss: 0.2880, Valid: 40.01%, Test: 12.17%
# Hits@50
# Run: 01, Epoch: 115, Loss: 0.2880, Valid: 47.55%, Test: 19.49%
# Hits@100
# Run: 01, Epoch: 115, Loss: 0.2880, Valid: 53.82%, Test: 32.50%
# ---
# Hits@20
# Run: 01, Epoch: 116, Loss: 0.2883, Valid: 44.32%, Test: 7.74%
# Hits@50
# Run: 01, Epoch: 116, Loss: 0.2883, Valid: 49.82%, Test: 16.35%
# Hits@100
# Run: 01, Epoch: 116, Loss: 0.2883, Valid: 55.52%, Test: 26.86%
# ---
# Hits@20
# Run: 01, Epoch: 117, Loss: 0.2863, Valid: 42.11%, Test: 13.63%
# Hits@50
# Run: 01, Epoch: 117, Loss: 0.2863, Valid: 48.68%, Test: 21.49%
# Hits@100
# Run: 01, Epoch: 117, Loss: 0.2863, Valid: 54.33%, Test: 32.06%
# ---
# Hits@20
# Run: 01, Epoch: 118, Loss: 0.2874, Valid: 41.11%, Test: 9.02%
# Hits@50
# Run: 01, Epoch: 118, Loss: 0.2874, Valid: 49.47%, Test: 18.96%
# Hits@100
# Run: 01, Epoch: 118, Loss: 0.2874, Valid: 55.61%, Test: 36.47%
# ---
# Hits@20
# Run: 01, Epoch: 119, Loss: 0.2854, Valid: 40.97%, Test: 12.98%
# Hits@50
# Run: 01, Epoch: 119, Loss: 0.2854, Valid: 49.69%, Test: 22.05%
# Hits@100
# Run: 01, Epoch: 119, Loss: 0.2854, Valid: 56.57%, Test: 38.66%
# ---
# Hits@20
# Run: 01, Epoch: 120, Loss: 0.2866, Valid: 44.63%, Test: 11.64%
# Hits@50
# Run: 01, Epoch: 120, Loss: 0.2866, Valid: 52.06%, Test: 22.10%
# Hits@100
# Run: 01, Epoch: 120, Loss: 0.2866, Valid: 57.78%, Test: 37.01%
# ---
# Hits@20
# Run: 01, Epoch: 121, Loss: 0.2850, Valid: 41.62%, Test: 10.18%
# Hits@50
# Run: 01, Epoch: 121, Loss: 0.2850, Valid: 48.44%, Test: 16.96%
# Hits@100
# Run: 01, Epoch: 121, Loss: 0.2850, Valid: 55.58%, Test: 27.08%
# ---
# Hits@20
# Run: 01, Epoch: 122, Loss: 0.2840, Valid: 41.14%, Test: 9.28%
# Hits@50
# Run: 01, Epoch: 122, Loss: 0.2840, Valid: 48.80%, Test: 17.92%
# Hits@100
# Run: 01, Epoch: 122, Loss: 0.2840, Valid: 55.01%, Test: 31.21%
# ---
# Hits@20
# Run: 01, Epoch: 123, Loss: 0.2823, Valid: 43.07%, Test: 9.15%
# Hits@50
# Run: 01, Epoch: 123, Loss: 0.2823, Valid: 49.46%, Test: 15.51%
# Hits@100
# Run: 01, Epoch: 123, Loss: 0.2823, Valid: 56.00%, Test: 29.90%
# ---
# Hits@20
# Run: 01, Epoch: 124, Loss: 0.2818, Valid: 42.01%, Test: 10.95%
# Hits@50
# Run: 01, Epoch: 124, Loss: 0.2818, Valid: 50.85%, Test: 17.87%
# Hits@100
# Run: 01, Epoch: 124, Loss: 0.2818, Valid: 56.75%, Test: 32.44%
# ---
# Hits@20
# Run: 01, Epoch: 125, Loss: 0.2815, Valid: 44.51%, Test: 10.07%
# Hits@50
# Run: 01, Epoch: 125, Loss: 0.2815, Valid: 51.46%, Test: 18.43%
# Hits@100
# Run: 01, Epoch: 125, Loss: 0.2815, Valid: 56.53%, Test: 30.39%
# ---
# Hits@20
# Run: 01, Epoch: 126, Loss: 0.2793, Valid: 44.31%, Test: 9.43%
# Hits@50
# Run: 01, Epoch: 126, Loss: 0.2793, Valid: 51.58%, Test: 17.25%
# Hits@100
# Run: 01, Epoch: 126, Loss: 0.2793, Valid: 56.86%, Test: 29.85%
# ---
# Hits@20
# Run: 01, Epoch: 127, Loss: 0.2791, Valid: 42.18%, Test: 10.92%
# Hits@50
# Run: 01, Epoch: 127, Loss: 0.2791, Valid: 49.34%, Test: 17.82%
# Hits@100
# Run: 01, Epoch: 127, Loss: 0.2791, Valid: 55.25%, Test: 32.43%
# ---
# Hits@20
# Run: 01, Epoch: 128, Loss: 0.2789, Valid: 46.10%, Test: 10.63%
# Hits@50
# Run: 01, Epoch: 128, Loss: 0.2789, Valid: 50.66%, Test: 18.37%
# Hits@100
# Run: 01, Epoch: 128, Loss: 0.2789, Valid: 56.52%, Test: 33.46%
# ---
# Hits@20
# Run: 01, Epoch: 129, Loss: 0.2775, Valid: 46.44%, Test: 9.64%
# Hits@50
# Run: 01, Epoch: 129, Loss: 0.2775, Valid: 52.26%, Test: 17.81%
# Hits@100
# Run: 01, Epoch: 129, Loss: 0.2775, Valid: 57.50%, Test: 34.10%
# ---
# Hits@20
# Run: 01, Epoch: 130, Loss: 0.2766, Valid: 42.12%, Test: 11.35%
# Hits@50
# Run: 01, Epoch: 130, Loss: 0.2766, Valid: 49.37%, Test: 17.60%
# Hits@100
# Run: 01, Epoch: 130, Loss: 0.2766, Valid: 55.94%, Test: 24.37%
# ---
# Hits@20
# Run: 01, Epoch: 131, Loss: 0.2774, Valid: 43.62%, Test: 9.32%
# Hits@50
# Run: 01, Epoch: 131, Loss: 0.2774, Valid: 50.75%, Test: 15.32%
# Hits@100
# Run: 01, Epoch: 131, Loss: 0.2774, Valid: 57.08%, Test: 25.28%
# ---
# Hits@20
# Run: 01, Epoch: 132, Loss: 0.2783, Valid: 47.21%, Test: 9.61%
# Hits@50
# Run: 01, Epoch: 132, Loss: 0.2783, Valid: 53.67%, Test: 15.91%
# Hits@100
# Run: 01, Epoch: 132, Loss: 0.2783, Valid: 59.32%, Test: 28.68%
# ---
# Hits@20
# Run: 01, Epoch: 133, Loss: 0.2765, Valid: 45.98%, Test: 9.65%
# Hits@50
# Run: 01, Epoch: 133, Loss: 0.2765, Valid: 50.95%, Test: 14.67%
# Hits@100
# Run: 01, Epoch: 133, Loss: 0.2765, Valid: 56.00%, Test: 28.20%
# ---
# Hits@20
# Run: 01, Epoch: 134, Loss: 0.2773, Valid: 48.03%, Test: 9.60%
# Hits@50
# Run: 01, Epoch: 134, Loss: 0.2773, Valid: 54.92%, Test: 17.70%
# Hits@100
# Run: 01, Epoch: 134, Loss: 0.2773, Valid: 59.78%, Test: 40.60%
# ---
# Hits@20
# Run: 01, Epoch: 135, Loss: 0.2769, Valid: 45.94%, Test: 9.93%
# Hits@50
# Run: 01, Epoch: 135, Loss: 0.2769, Valid: 52.11%, Test: 16.04%
# Hits@100
# Run: 01, Epoch: 135, Loss: 0.2769, Valid: 57.75%, Test: 23.44%
# ---
# Hits@20
# Run: 01, Epoch: 136, Loss: 0.2740, Valid: 47.05%, Test: 8.15%
# Hits@50
# Run: 01, Epoch: 136, Loss: 0.2740, Valid: 52.07%, Test: 14.37%
# Hits@100
# Run: 01, Epoch: 136, Loss: 0.2740, Valid: 57.96%, Test: 24.73%
# ---
# Hits@20
# Run: 01, Epoch: 137, Loss: 0.2743, Valid: 44.41%, Test: 10.37%
# Hits@50
# Run: 01, Epoch: 137, Loss: 0.2743, Valid: 54.05%, Test: 17.53%
# Hits@100
# Run: 01, Epoch: 137, Loss: 0.2743, Valid: 58.12%, Test: 29.78%
# ---
# Hits@20
# Run: 01, Epoch: 138, Loss: 0.2742, Valid: 48.14%, Test: 9.88%
# Hits@50
# Run: 01, Epoch: 138, Loss: 0.2742, Valid: 54.99%, Test: 15.15%
# Hits@100
# Run: 01, Epoch: 138, Loss: 0.2742, Valid: 59.74%, Test: 25.65%
# ---
# Hits@20
# Run: 01, Epoch: 139, Loss: 0.2739, Valid: 47.49%, Test: 6.48%
# Hits@50
# Run: 01, Epoch: 139, Loss: 0.2739, Valid: 53.49%, Test: 14.59%
# Hits@100
# Run: 01, Epoch: 139, Loss: 0.2739, Valid: 58.34%, Test: 28.31%
# ---
# Hits@20
# Run: 01, Epoch: 140, Loss: 0.2747, Valid: 46.84%, Test: 11.00%
# Hits@50
# Run: 01, Epoch: 140, Loss: 0.2747, Valid: 53.52%, Test: 16.22%
# Hits@100
# Run: 01, Epoch: 140, Loss: 0.2747, Valid: 57.82%, Test: 27.49%
# ---
# Hits@20
# Run: 01, Epoch: 141, Loss: 0.2703, Valid: 49.39%, Test: 8.81%
# Hits@50
# Run: 01, Epoch: 141, Loss: 0.2703, Valid: 55.63%, Test: 17.33%
# Hits@100
# Run: 01, Epoch: 141, Loss: 0.2703, Valid: 60.04%, Test: 28.76%
# ---
# Hits@20
# Run: 01, Epoch: 142, Loss: 0.2717, Valid: 41.66%, Test: 9.82%
# Hits@50
# Run: 01, Epoch: 142, Loss: 0.2717, Valid: 53.60%, Test: 17.05%
# Hits@100
# Run: 01, Epoch: 142, Loss: 0.2717, Valid: 58.58%, Test: 29.43%
# ---
# Hits@20
# Run: 01, Epoch: 143, Loss: 0.2705, Valid: 44.29%, Test: 12.54%
# Hits@50
# Run: 01, Epoch: 143, Loss: 0.2705, Valid: 51.45%, Test: 17.52%
# Hits@100
# Run: 01, Epoch: 143, Loss: 0.2705, Valid: 56.71%, Test: 25.60%
# ---
# Hits@20
# Run: 01, Epoch: 144, Loss: 0.2678, Valid: 45.15%, Test: 9.11%
# Hits@50
# Run: 01, Epoch: 144, Loss: 0.2678, Valid: 53.69%, Test: 19.90%
# Hits@100
# Run: 01, Epoch: 144, Loss: 0.2678, Valid: 59.22%, Test: 37.40%
# ---
# Hits@20
# Run: 01, Epoch: 145, Loss: 0.2688, Valid: 44.98%, Test: 10.27%
# Hits@50
# Run: 01, Epoch: 145, Loss: 0.2688, Valid: 52.48%, Test: 18.37%
# Hits@100
# Run: 01, Epoch: 145, Loss: 0.2688, Valid: 57.39%, Test: 31.01%
# ---
# Hits@20
# Run: 01, Epoch: 146, Loss: 0.2677, Valid: 47.23%, Test: 7.58%
# Hits@50
# Run: 01, Epoch: 146, Loss: 0.2677, Valid: 55.40%, Test: 15.66%
# Hits@100
# Run: 01, Epoch: 146, Loss: 0.2677, Valid: 59.28%, Test: 24.26%
# ---
# Hits@20
# Run: 01, Epoch: 147, Loss: 0.2698, Valid: 44.70%, Test: 8.15%
# Hits@50
# Run: 01, Epoch: 147, Loss: 0.2698, Valid: 52.26%, Test: 15.85%
# Hits@100
# Run: 01, Epoch: 147, Loss: 0.2698, Valid: 56.56%, Test: 24.84%
# ---
# Hits@20
# Run: 01, Epoch: 148, Loss: 0.2695, Valid: 48.31%, Test: 8.40%
# Hits@50
# Run: 01, Epoch: 148, Loss: 0.2695, Valid: 55.08%, Test: 15.45%
# Hits@100
# Run: 01, Epoch: 148, Loss: 0.2695, Valid: 59.21%, Test: 39.27%
# ---
# Hits@20
# Run: 01, Epoch: 149, Loss: 0.2693, Valid: 49.86%, Test: 10.39%
# Hits@50
# Run: 01, Epoch: 149, Loss: 0.2693, Valid: 55.31%, Test: 20.51%
# Hits@100
# Run: 01, Epoch: 149, Loss: 0.2693, Valid: 59.80%, Test: 36.00%
# ---
# Hits@20
# Run: 01, Epoch: 150, Loss: 0.2671, Valid: 48.89%, Test: 7.44%
# Hits@50
# Run: 01, Epoch: 150, Loss: 0.2671, Valid: 54.51%, Test: 14.76%
# Hits@100
# Run: 01, Epoch: 150, Loss: 0.2671, Valid: 59.19%, Test: 31.43%
# ---
# Hits@20
# Run: 01, Epoch: 151, Loss: 0.2658, Valid: 48.07%, Test: 9.30%
# Hits@50
# Run: 01, Epoch: 151, Loss: 0.2658, Valid: 54.25%, Test: 16.25%
# Hits@100
# Run: 01, Epoch: 151, Loss: 0.2658, Valid: 59.84%, Test: 25.55%
# ---
# Hits@20
# Run: 01, Epoch: 152, Loss: 0.2675, Valid: 49.10%, Test: 7.73%
# Hits@50
# Run: 01, Epoch: 152, Loss: 0.2675, Valid: 54.98%, Test: 14.57%
# Hits@100
# Run: 01, Epoch: 152, Loss: 0.2675, Valid: 59.80%, Test: 27.59%
# ---
# Hits@20
# Run: 01, Epoch: 153, Loss: 0.2652, Valid: 47.65%, Test: 10.46%
# Hits@50
# Run: 01, Epoch: 153, Loss: 0.2652, Valid: 55.58%, Test: 15.85%
# Hits@100
# Run: 01, Epoch: 153, Loss: 0.2652, Valid: 59.29%, Test: 27.71%
# ---
# Hits@20
# Run: 01, Epoch: 154, Loss: 0.2656, Valid: 48.55%, Test: 8.37%
# Hits@50
# Run: 01, Epoch: 173, Loss: 0.2559, Valid: 61.56%, Test: 34.67%
# ---
# Hits@20
# Run: 01, Epoch: 174, Loss: 0.2559, Valid: 47.11%, Test: 6.15%
# Hits@50
# Run: 01, Epoch: 174, Loss: 0.2559, Valid: 55.66%, Test: 11.84%
# Hits@100
# Run: 01, Epoch: 174, Loss: 0.2559, Valid: 60.75%, Test: 26.77%
# ---
# Hits@20
# Run: 01, Epoch: 175, Loss: 0.2555, Valid: 50.50%, Test: 5.98%
# Hits@50
# Run: 01, Epoch: 175, Loss: 0.2555, Valid: 58.11%, Test: 11.48%
# Hits@100
# Run: 01, Epoch: 175, Loss: 0.2555, Valid: 61.93%, Test: 23.80%
# ---
# Hits@20
# Run: 01, Epoch: 176, Loss: 0.2566, Valid: 48.52%, Test: 5.03%
# Hits@50
# Run: 01, Epoch: 176, Loss: 0.2566, Valid: 54.45%, Test: 22.08%
# Hits@100
# Run: 01, Epoch: 176, Loss: 0.2566, Valid: 60.82%, Test: 48.01%
# ---
# Hits@20
# Run: 01, Epoch: 177, Loss: 0.2536, Valid: 50.00%, Test: 5.78%
# Hits@50
# Run: 01, Epoch: 177, Loss: 0.2536, Valid: 59.56%, Test: 15.23%
# Hits@100
# Run: 01, Epoch: 177, Loss: 0.2536, Valid: 62.72%, Test: 52.50%
# ---
# Hits@20
# Run: 01, Epoch: 178, Loss: 0.2559, Valid: 50.53%, Test: 5.44%
# Hits@50
# Run: 01, Epoch: 178, Loss: 0.2559, Valid: 58.36%, Test: 13.37%
# Hits@100
# Run: 01, Epoch: 178, Loss: 0.2559, Valid: 62.25%, Test: 33.88%
# ---
# Hits@20
# Run: 01, Epoch: 179, Loss: 0.2536, Valid: 48.66%, Test: 5.86%
# Hits@50
# Run: 01, Epoch: 179, Loss: 0.2536, Valid: 58.13%, Test: 13.96%
# Hits@100
# Run: 01, Epoch: 179, Loss: 0.2536, Valid: 61.84%, Test: 34.73%
# ---
# Hits@20
# Run: 01, Epoch: 180, Loss: 0.2549, Valid: 43.07%, Test: 7.64%
# Hits@50
# Run: 01, Epoch: 180, Loss: 0.2549, Valid: 53.50%, Test: 14.31%
# Hits@100
# Run: 01, Epoch: 180, Loss: 0.2549, Valid: 59.78%, Test: 30.89%
# ---
# Hits@20
# Run: 01, Epoch: 181, Loss: 0.2550, Valid: 48.19%, Test: 7.13%
# Hits@50
# Run: 01, Epoch: 181, Loss: 0.2550, Valid: 57.66%, Test: 15.22%
# Hits@100
# Run: 01, Epoch: 181, Loss: 0.2550, Valid: 62.63%, Test: 34.93%
# ---
# Hits@20
# Run: 01, Epoch: 182, Loss: 0.2556, Valid: 49.56%, Test: 5.79%
# Hits@50
# Run: 01, Epoch: 182, Loss: 0.2556, Valid: 58.15%, Test: 16.18%
# Hits@100
# Run: 01, Epoch: 182, Loss: 0.2556, Valid: 62.81%, Test: 39.41%
# ---
# Hits@20
# Run: 01, Epoch: 183, Loss: 0.2521, Valid: 49.29%, Test: 5.12%
# Hits@50
# Run: 01, Epoch: 183, Loss: 0.2521, Valid: 58.90%, Test: 12.34%
# Hits@100
# Run: 01, Epoch: 183, Loss: 0.2521, Valid: 63.05%, Test: 31.20%
# ---
# Hits@20
# Run: 01, Epoch: 184, Loss: 0.2535, Valid: 51.56%, Test: 8.32%
# Hits@50
# Run: 01, Epoch: 184, Loss: 0.2535, Valid: 59.05%, Test: 25.79%
# Hits@100
# Run: 01, Epoch: 184, Loss: 0.2535, Valid: 62.51%, Test: 59.60%
# ---
# Hits@20
# Run: 01, Epoch: 185, Loss: 0.2530, Valid: 48.09%, Test: 6.99%
# Hits@50
# Run: 01, Epoch: 185, Loss: 0.2530, Valid: 57.14%, Test: 19.99%
# Hits@100
# Run: 01, Epoch: 185, Loss: 0.2530, Valid: 61.78%, Test: 54.85%
# ---
# Hits@20
# Run: 01, Epoch: 186, Loss: 0.2514, Valid: 50.98%, Test: 6.33%
# Hits@50
# Run: 01, Epoch: 186, Loss: 0.2514, Valid: 57.95%, Test: 18.37%
# Hits@100
# Run: 01, Epoch: 186, Loss: 0.2514, Valid: 62.21%, Test: 49.36%
# ---
# Hits@20
# Run: 01, Epoch: 187, Loss: 0.2528, Valid: 50.34%, Test: 6.19%
# Hits@50
# Run: 01, Epoch: 187, Loss: 0.2528, Valid: 58.37%, Test: 15.73%
# Hits@100
# Run: 01, Epoch: 187, Loss: 0.2528, Valid: 62.35%, Test: 38.83%
# ---
# Hits@20
# Run: 01, Epoch: 188, Loss: 0.2516, Valid: 48.22%, Test: 5.40%
# Hits@50
# Run: 01, Epoch: 188, Loss: 0.2516, Valid: 58.17%, Test: 16.30%
# Hits@100
# Run: 01, Epoch: 188, Loss: 0.2516, Valid: 63.12%, Test: 42.89%
# ---
# Hits@20
# Run: 01, Epoch: 189, Loss: 0.2507, Valid: 46.99%, Test: 6.63%
# Hits@50
# Run: 01, Epoch: 189, Loss: 0.2507, Valid: 56.09%, Test: 14.22%
# Hits@100
# Run: 01, Epoch: 189, Loss: 0.2507, Valid: 61.72%, Test: 27.13%
# ---
# Hits@20
# Run: 01, Epoch: 190, Loss: 0.2521, Valid: 51.81%, Test: 6.75%
# Hits@50
# Run: 01, Epoch: 190, Loss: 0.2521, Valid: 58.94%, Test: 17.62%
# Hits@100
# Run: 01, Epoch: 190, Loss: 0.2521, Valid: 62.62%, Test: 42.96%
# ---
# Hits@20
# Run: 01, Epoch: 191, Loss: 0.2508, Valid: 49.77%, Test: 6.68%
# Hits@50
# Run: 01, Epoch: 191, Loss: 0.2508, Valid: 58.28%, Test: 15.71%
# Hits@100
# Run: 01, Epoch: 191, Loss: 0.2508, Valid: 62.74%, Test: 35.56%
# ---
# Hits@20
# Run: 01, Epoch: 192, Loss: 0.2500, Valid: 49.45%, Test: 7.84%
# Hits@50
# Run: 01, Epoch: 192, Loss: 0.2500, Valid: 58.79%, Test: 13.86%
# Hits@100
# Run: 01, Epoch: 192, Loss: 0.2500, Valid: 61.90%, Test: 25.81%
# ---
# Run: 01, Epoch: 202, Loss: 0.2476, Valid: 64.24%, Test: 44.85%
# ---
# Hits@20
# Run: 01, Epoch: 203, Loss: 0.2469, Valid: 52.25%, Test: 4.75%
# Hits@50
# Run: 01, Epoch: 203, Loss: 0.2469, Valid: 59.78%, Test: 22.21%
# Hits@100
# Run: 01, Epoch: 203, Loss: 0.2469, Valid: 63.15%, Test: 59.25%
# ---
# Hits@20
# Run: 01, Epoch: 204, Loss: 0.2484, Valid: 47.89%, Test: 6.73%
# Hits@50
# Run: 01, Epoch: 204, Loss: 0.2484, Valid: 57.19%, Test: 18.50%
# Hits@100
# Run: 01, Epoch: 204, Loss: 0.2484, Valid: 62.50%, Test: 42.12%
# ---
# Hits@20
# Run: 01, Epoch: 205, Loss: 0.2489, Valid: 53.86%, Test: 5.18%
# Hits@50
# Run: 01, Epoch: 205, Loss: 0.2489, Valid: 59.57%, Test: 21.05%
# Hits@100
# Run: 01, Epoch: 205, Loss: 0.2489, Valid: 63.63%, Test: 62.80%
# ---
# Hits@20
# Run: 01, Epoch: 206, Loss: 0.2458, Valid: 46.60%, Test: 3.94%
# Hits@50
# Run: 01, Epoch: 206, Loss: 0.2458, Valid: 59.36%, Test: 14.82%
# Hits@100
# Run: 01, Epoch: 206, Loss: 0.2458, Valid: 63.42%, Test: 55.92%
# ---
# Hits@20
# Run: 01, Epoch: 207, Loss: 0.2454, Valid: 52.01%, Test: 4.82%
# Hits@50
# Run: 01, Epoch: 207, Loss: 0.2454, Valid: 59.29%, Test: 15.40%
# Hits@100
# Run: 01, Epoch: 207, Loss: 0.2454, Valid: 63.71%, Test: 39.79%
# ---
# Hits@20
# Run: 01, Epoch: 208, Loss: 0.2436, Valid: 48.66%, Test: 4.52%
# Hits@50
# Run: 01, Epoch: 208, Loss: 0.2436, Valid: 58.97%, Test: 14.57%
# Hits@100
# Run: 01, Epoch: 208, Loss: 0.2436, Valid: 63.25%, Test: 52.48%
# ---
# Hits@20
# Run: 01, Epoch: 209, Loss: 0.2485, Valid: 49.74%, Test: 3.51%
# Hits@50
# Run: 01, Epoch: 209, Loss: 0.2485, Valid: 58.34%, Test: 14.55%
# Hits@100
# Run: 01, Epoch: 209, Loss: 0.2485, Valid: 63.30%, Test: 45.30%
# ---
# Hits@20
# Run: 01, Epoch: 210, Loss: 0.2450, Valid: 55.04%, Test: 5.73%
# Hits@50
# Run: 01, Epoch: 210, Loss: 0.2450, Valid: 60.25%, Test: 27.98%
# Hits@100
# Run: 01, Epoch: 210, Loss: 0.2450, Valid: 64.13%, Test: 73.91%
# ---
# Hits@20
# Run: 01, Epoch: 211, Loss: 0.2431, Valid: 53.73%, Test: 3.71%
# Hits@50
# Run: 01, Epoch: 211, Loss: 0.2431, Valid: 59.76%, Test: 14.39%
# Hits@100
# Run: 01, Epoch: 211, Loss: 0.2431, Valid: 64.14%, Test: 63.60%
# ---
# Hits@20
# Run: 01, Epoch: 212, Loss: 0.2436, Valid: 51.82%, Test: 2.74%
# Hits@50
# Hits@20
# Run: 01, Epoch: 222, Loss: 0.2421, Valid: 54.50%, Test: 4.59%
# Hits@50
# Run: 01, Epoch: 222, Loss: 0.2421, Valid: 61.91%, Test: 22.79%
# Hits@100
# Run: 01, Epoch: 222, Loss: 0.2421, Valid: 65.00%, Test: 64.75%
# ---
# Hits@20
# ...
# Hits@100
# Run: 01, Epoch: 329, Loss: 0.2215, Valid: 67.86%, Test: 84.45%
# ---
# Hits@20
# Run: 01, Epoch: 330, Loss: 0.2208, Valid: 59.32%, Test: 14.18%
# Hits@50
# Run: 01, Epoch: 330, Loss: 0.2208, Valid: 65.60%, Test: 61.19%
# Hits@100
# Run: 01, Epoch: 330, Loss: 0.2208, Valid: 68.23%, Test: 83.99%
# ---
# Hits@20
# Run: 01, Epoch: 331, Loss: 0.2214, Valid: 60.47%, Test: 19.34%
# Hits@50
# Run: 01, Epoch: 331, Loss: 0.2214, Valid: 64.56%, Test: 67.57%
# Hits@100
# Run: 01, Epoch: 331, Loss: 0.2214, Valid: 67.25%, Test: 83.80%
# ---
# Hits@20
# Run: 01, Epoch: 332, Loss: 0.2233, Valid: 60.71%, Test: 9.69%
# Hits@50
# Run: 01, Epoch: 332, Loss: 0.2233, Valid: 64.74%, Test: 54.26%
# Hits@100
# Run: 01, Epoch: 332, Loss: 0.2233, Valid: 67.61%, Test: 81.15%
# ---
# Hits@20
# Run: 01, Epoch: 333, Loss: 0.2211, Valid: 59.14%, Test: 6.69%
# Hits@50
# Run: 01, Epoch: 333, Loss: 0.2211, Valid: 65.22%, Test: 53.08%
# Hits@100
# Run: 01, Epoch: 333, Loss: 0.2211, Valid: 67.97%, Test: 83.01%
# ---
# Hits@20
# Run: 01, Epoch: 334, Loss: 0.2211, Valid: 60.41%, Test: 6.96%
# Hits@50
# Run: 01, Epoch: 334, Loss: 0.2211, Valid: 64.92%, Test: 60.86%
# Hits@100
# Run: 01, Epoch: 334, Loss: 0.2211, Valid: 67.96%, Test: 81.98%
# ---
# Hits@20
# Run: 01, Epoch: 335, Loss: 0.2206, Valid: 58.73%, Test: 16.97%
# Hits@50
# Run: 01, Epoch: 335, Loss: 0.2206, Valid: 65.32%, Test: 65.75%
# Hits@100
# Run: 01, Epoch: 335, Loss: 0.2206, Valid: 67.58%, Test: 83.92%
# ---
# Hits@20
# Run: 01, Epoch: 336, Loss: 0.2214, Valid: 56.38%, Test: 10.73%
# Hits@50
# Run: 01, Epoch: 336, Loss: 0.2214, Valid: 65.15%, Test: 46.51%
# Hits@100
# Run: 01, Epoch: 336, Loss: 0.2214, Valid: 67.72%, Test: 77.53%
# ---
# Hits@20
# Run: 01, Epoch: 337, Loss: 0.2202, Valid: 59.70%, Test: 14.99%
# Hits@50
# Run: 01, Epoch: 337, Loss: 0.2202, Valid: 65.53%, Test: 60.47%
# Hits@100
# Run: 01, Epoch: 337, Loss: 0.2202, Valid: 68.17%, Test: 83.33%
# ---
# Hits@20
# Run: 01, Epoch: 338, Loss: 0.2201, Valid: 60.29%, Test: 15.53%
# Hits@50
# Run: 01, Epoch: 338, Loss: 0.2201, Valid: 64.88%, Test: 58.24%
# Hits@100
# Run: 01, Epoch: 338, Loss: 0.2201, Valid: 67.29%, Test: 82.57%
# ---
# Hits@20
# Run: 01, Epoch: 339, Loss: 0.2212, Valid: 61.16%, Test: 24.24%
# Hits@50
# Run: 01, Epoch: 339, Loss: 0.2212, Valid: 66.10%, Test: 58.92%
# Hits@100
# Run: 01, Epoch: 339, Loss: 0.2212, Valid: 68.12%, Test: 83.08%
# ---
# Hits@20
# Run: 01, Epoch: 340, Loss: 0.2203, Valid: 61.32%, Test: 7.82%
# Hits@50
# Run: 01, Epoch: 340, Loss: 0.2203, Valid: 64.89%, Test: 51.70%
# Hits@100
# Run: 01, Epoch: 340, Loss: 0.2203, Valid: 67.43%, Test: 80.36%
# ---
# Hits@20
# Run: 01, Epoch: 341, Loss: 0.2198, Valid: 60.32%, Test: 10.15%
# Hits@50
# Run: 01, Epoch: 341, Loss: 0.2198, Valid: 65.64%, Test: 60.70%
# Hits@100
# Run: 01, Epoch: 341, Loss: 0.2198, Valid: 68.14%, Test: 83.34%
# ---
# Hits@20
# Run: 01, Epoch: 342, Loss: 0.2197, Valid: 58.27%, Test: 14.90%
# Hits@50
# Run: 01, Epoch: 342, Loss: 0.2197, Valid: 64.83%, Test: 58.99%
# Hits@100
# Run: 01, Epoch: 342, Loss: 0.2197, Valid: 67.47%, Test: 81.58%
# ---
# Hits@20
# Run: 01, Epoch: 343, Loss: 0.2193, Valid: 57.77%, Test: 14.78%
# Hits@50
# Run: 01, Epoch: 343, Loss: 0.2193, Valid: 65.24%, Test: 55.53%
# Hits@100
# Run: 01, Epoch: 343, Loss: 0.2193, Valid: 67.44%, Test: 82.72%
# ---
# Hits@20
# Run: 01, Epoch: 344, Loss: 0.2212, Valid: 60.33%, Test: 13.45%
# Hits@50
# Run: 01, Epoch: 344, Loss: 0.2212, Valid: 65.39%, Test: 61.45%
# Hits@100
# Run: 01, Epoch: 344, Loss: 0.2212, Valid: 67.82%, Test: 84.22%
# ---
# Hits@20
# Run: 01, Epoch: 345, Loss: 0.2179, Valid: 60.81%, Test: 13.64%
# Hits@50
# Run: 01, Epoch: 345, Loss: 0.2179, Valid: 65.40%, Test: 59.85%
# Hits@100
# Run: 01, Epoch: 345, Loss: 0.2179, Valid: 68.02%, Test: 83.52%
# ---
# Hits@20
# Run: 01, Epoch: 346, Loss: 0.2203, Valid: 59.37%, Test: 16.69%
# Hits@50
# Run: 01, Epoch: 346, Loss: 0.2203, Valid: 64.71%, Test: 65.48%
# Hits@100
# Run: 01, Epoch: 346, Loss: 0.2203, Valid: 67.06%, Test: 82.83%
# ---
# Hits@20
# Run: 01, Epoch: 347, Loss: 0.2205, Valid: 59.44%, Test: 26.96%
# Hits@50
# Run: 01, Epoch: 347, Loss: 0.2205, Valid: 64.80%, Test: 67.36%
# Hits@100
# Run: 01, Epoch: 347, Loss: 0.2205, Valid: 68.10%, Test: 83.58%
# ---
# Hits@20
# Run: 01, Epoch: 348, Loss: 0.2207, Valid: 60.33%, Test: 5.72%
# Hits@50
# Run: 01, Epoch: 348, Loss: 0.2207, Valid: 65.51%, Test: 47.46%
# Hits@100
# Run: 01, Epoch: 348, Loss: 0.2207, Valid: 67.84%, Test: 83.62%
# ---
# Hits@20
# Run: 01, Epoch: 349, Loss: 0.2188, Valid: 60.76%, Test: 17.00%
# Hits@50
# Run: 01, Epoch: 349, Loss: 0.2188, Valid: 65.46%, Test: 56.15%
# Hits@100
# Run: 01, Epoch: 349, Loss: 0.2188, Valid: 67.97%, Test: 84.88%
# ---
# Hits@20
# Run: 01, Epoch: 350, Loss: 0.2178, Valid: 58.45%, Test: 24.29%
# Hits@50
# Run: 01, Epoch: 350, Loss: 0.2178, Valid: 65.64%, Test: 62.52%
# Hits@100
# Run: 01, Epoch: 350, Loss: 0.2178, Valid: 68.43%, Test: 84.15%
# ---
# Hits@20
# Run: 01, Epoch: 351, Loss: 0.2187, Valid: 61.78%, Test: 38.85%
# Hits@50
# Run: 01, Epoch: 351, Loss: 0.2187, Valid: 65.20%, Test: 64.40%
# Hits@100
# Run: 01, Epoch: 351, Loss: 0.2187, Valid: 68.05%, Test: 83.92%
# ---
# Hits@20
# Run: 01, Epoch: 352, Loss: 0.2206, Valid: 59.82%, Test: 18.75%
# Hits@50
# Run: 01, Epoch: 352, Loss: 0.2206, Valid: 65.03%, Test: 64.36%
# Hits@100
# Run: 01, Epoch: 352, Loss: 0.2206, Valid: 67.77%, Test: 83.80%
# ---
# Hits@20
# Run: 01, Epoch: 353, Loss: 0.2201, Valid: 61.03%, Test: 15.91%
# Hits@50
# Run: 01, Epoch: 353, Loss: 0.2201, Valid: 65.43%, Test: 66.53%
# Hits@100
# Run: 01, Epoch: 353, Loss: 0.2201, Valid: 68.40%, Test: 83.96%
# ---
# Hits@20
# Run: 01, Epoch: 354, Loss: 0.2188, Valid: 60.80%, Test: 7.02%
# Hits@50
# Run: 01, Epoch: 354, Loss: 0.2188, Valid: 65.58%, Test: 41.71%
# Hits@100
# Run: 01, Epoch: 354, Loss: 0.2188, Valid: 67.71%, Test: 83.20%
# ---
# Hits@20
# Run: 01, Epoch: 355, Loss: 0.2179, Valid: 58.74%, Test: 4.99%
# Hits@50
# Run: 01, Epoch: 355, Loss: 0.2179, Valid: 64.89%, Test: 39.03%
# Hits@100
# Run: 01, Epoch: 355, Loss: 0.2179, Valid: 68.05%, Test: 81.16%
# ---
# Hits@20
# Run: 01, Epoch: 356, Loss: 0.2196, Valid: 61.30%, Test: 9.97%
# Hits@50
# Run: 01, Epoch: 356, Loss: 0.2196, Valid: 65.81%, Test: 59.18%
# Hits@100
# Run: 01, Epoch: 356, Loss: 0.2196, Valid: 68.28%, Test: 83.46%
# ---
# Hits@20
# Run: 01, Epoch: 357, Loss: 0.2190, Valid: 60.42%, Test: 16.82%
# Hits@50
# Run: 01, Epoch: 357, Loss: 0.2190, Valid: 64.67%, Test: 62.57%
# Hits@100
# Run: 01, Epoch: 357, Loss: 0.2190, Valid: 67.57%, Test: 84.29%
# ---
# Hits@20
# Run: 01, Epoch: 358, Loss: 0.2181, Valid: 60.67%, Test: 10.75%
# Hits@50
# Run: 01, Epoch: 358, Loss: 0.2181, Valid: 65.37%, Test: 54.41%
# Hits@100
# Run: 01, Epoch: 358, Loss: 0.2181, Valid: 68.14%, Test: 83.39%
# ---
# Hits@20
# Run: 01, Epoch: 359, Loss: 0.2175, Valid: 61.49%, Test: 21.96%
# Hits@50
# Run: 01, Epoch: 359, Loss: 0.2175, Valid: 65.83%, Test: 69.04%
# Hits@100
# Run: 01, Epoch: 359, Loss: 0.2175, Valid: 68.56%, Test: 84.64%
# ---
# Hits@20
# Run: 01, Epoch: 360, Loss: 0.2177, Valid: 62.58%, Test: 32.47%
# Hits@50
# Run: 01, Epoch: 360, Loss: 0.2177, Valid: 66.35%, Test: 75.60%
# Hits@100
# Run: 01, Epoch: 360, Loss: 0.2177, Valid: 68.63%, Test: 85.42%
# ---
# Hits@20
# Run: 01, Epoch: 361, Loss: 0.2176, Valid: 61.11%, Test: 34.06%
# Hits@50
# Run: 01, Epoch: 361, Loss: 0.2176, Valid: 65.78%, Test: 65.71%
# Hits@100
# Run: 01, Epoch: 361, Loss: 0.2176, Valid: 68.35%, Test: 83.01%
# ---
# Hits@20
# Run: 01, Epoch: 362, Loss: 0.2198, Valid: 60.81%, Test: 8.04%
# Hits@50
# Run: 01, Epoch: 362, Loss: 0.2198, Valid: 65.26%, Test: 41.87%
# Hits@100
# Run: 01, Epoch: 362, Loss: 0.2198, Valid: 68.27%, Test: 81.75%
# ---
# Hits@20
# Run: 01, Epoch: 363, Loss: 0.2190, Valid: 59.36%, Test: 19.68%
# Hits@50
# Run: 01, Epoch: 363, Loss: 0.2190, Valid: 65.61%, Test: 54.94%
# Hits@100
# Run: 01, Epoch: 363, Loss: 0.2190, Valid: 67.91%, Test: 83.63%
# ---
# Hits@20
# Run: 01, Epoch: 364, Loss: 0.2175, Valid: 59.37%, Test: 12.22%
# Hits@50
# Run: 01, Epoch: 364, Loss: 0.2175, Valid: 65.38%, Test: 55.46%
# Hits@100
# Run: 01, Epoch: 364, Loss: 0.2175, Valid: 68.15%, Test: 83.72%
# ---
# Hits@20
# Run: 01, Epoch: 365, Loss: 0.2187, Valid: 58.21%, Test: 7.87%
# Hits@50
# Run: 01, Epoch: 365, Loss: 0.2187, Valid: 64.40%, Test: 43.31%
# Hits@100
# Run: 01, Epoch: 365, Loss: 0.2187, Valid: 67.68%, Test: 78.82%
# ---
# Hits@20
# Run: 01, Epoch: 366, Loss: 0.2176, Valid: 60.73%, Test: 28.37%
# Hits@50
# Run: 01, Epoch: 366, Loss: 0.2176, Valid: 66.00%, Test: 70.30%
# Hits@100
# Run: 01, Epoch: 366, Loss: 0.2176, Valid: 68.05%, Test: 85.17%
# ---
# Hits@20
# Run: 01, Epoch: 367, Loss: 0.2167, Valid: 60.83%, Test: 11.21%
# Hits@50
# Run: 01, Epoch: 396, Loss: 0.2150, Valid: 66.31%, Test: 53.85%
# Hits@100
# Run: 01, Epoch: 396, Loss: 0.2150, Valid: 68.70%, Test: 84.19%
# ---
# Hits@20
# Run: 01, Epoch: 397, Loss: 0.2141, Valid: 61.49%, Test: 35.72%
# Hits@50
# Run: 01, Epoch: 397, Loss: 0.2141, Valid: 66.20%, Test: 77.46%
# Hits@100
# Run: 01, Epoch: 397, Loss: 0.2141, Valid: 68.48%, Test: 86.98%
# ---
# Hits@20
# Run: 01, Epoch: 398, Loss: 0.2158, Valid: 59.04%, Test: 34.39%
# Hits@50
# Run: 01, Epoch: 398, Loss: 0.2158, Valid: 65.46%, Test: 70.01%
# Hits@100
# Run: 01, Epoch: 398, Loss: 0.2158, Valid: 68.61%, Test: 85.90%
# ---
# Hits@20
# Run: 01, Epoch: 399, Loss: 0.2136, Valid: 58.29%, Test: 3.71%
# Hits@50
# Run: 01, Epoch: 399, Loss: 0.2136, Valid: 65.22%, Test: 39.84%
# Hits@100
# Run: 01, Epoch: 399, Loss: 0.2136, Valid: 68.13%, Test: 83.15%
# ---
# Hits@20
# Run: 01, Epoch: 400, Loss: 0.2165, Valid: 61.12%, Test: 22.28%
# Hits@50
# Run: 01, Epoch: 400, Loss: 0.2165, Valid: 66.47%, Test: 65.08%
# Hits@100
# Run: 01, Epoch: 400, Loss: 0.2165, Valid: 68.68%, Test: 86.23%
# ---
# Hits@20
# Run 01:
# Highest Valid: 62.59
#    Final Test: 11.53
# Hits@50
# Run 01:
# Highest Valid: 66.69
#    Final Test: 73.67
# Hits@100
# Run 01:
# Highest Valid: 68.92
#    Final Test: 84.98
# Hits@20
# All runs:
# Highest Valid: 62.5917 ± nan
#    Final Test: 11.5297 ± nan
# Hits@50
# All runs:
# Highest Valid: 66.6901 ± nan
#    Final Test: 73.6744 ± nan
# Hits@100
# All runs:
# Highest Valid: 68.9237 ± nan
#    Final Test: 84.9846 ± nan

# %%
with open('data/6/all_pos_valid_pred.pickle', 'wb') as handle:
    pickle.dump(all_pos_valid_pred, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('data/6/all_neg_valid_pred.pickle', 'wb') as handle:
    pickle.dump(all_neg_valid_pred, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('data/6/all_pos_test_pred.pickle', 'wb') as handle:
    pickle.dump(all_pos_test_pred, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('data/6/all_neg_test_pred.pickle', 'wb') as handle:
    pickle.dump(all_neg_test_pred, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
pos_valid_pred, neg_valid_pred, pos_test_pred, neg_test_pred
# Out:
# tensor([0.5568, 0.6987, 0.7311,  ..., 0.7074, 0.6788, 0.7220])

# %%
with open('data/4/pos_valid_pred.pickle', 'wb') as handle:
    pickle.dump(pos_valid_pred, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('data/4/neg_valid_pred.pickle', 'wb') as handle:
    pickle.dump(neg_valid_pred, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('data/4/pos_test_pred.pickle', 'wb') as handle:
    pickle.dump(pos_test_pred, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('data/4/neg_test_pred.pickle', 'wb') as handle:
    pickle.dump(neg_test_pred, handle, protocol=pickle.HIGHEST_PROTOCOL)
